# %%
# -*- coding: utf-8 -*-
from bs4 import BeautifulSoup
import time
import random
import re
from tqdm import tqdm
import pandas as pd
import numpy as np
import time
import requests
import sys
import json
import pickle
from itertools import combinations

from konlpy.tag import Komoran

# bigram 생성에 필요한 library
from gensim.models import Phrases
from gensim.models.phrases import Phraser

# vectorize & lda에 필요한 library
from gensim import corpora
from gensim.models.ldamodel import LdaModel

# gensim의 ldamodel에 최적화된 라이브러리
import pyLDAvis
import pyLDAvis.gensim_models as gensimvis

# %%
with open('./final_model/all_contents_refined_dup.pickle', 'rb') as f:
    all_contents_refined = pickle.load(f)
    
with open('./final_model/corpus.pickle', 'rb') as f:
    corpus = pickle.load(f)
    
with open('./final_model/dictionary.pickle', 'rb') as f:
    dictionary = pickle.load(f)
    
with open('./final_model/merged.pickle', 'rb') as f:
    merged = pickle.load(f)
    
with open('./final_model/topic6_dict.pickle', 'rb') as f:
    topic6_dict = pickle.load(f)

# %%
model_saved = LdaModel.load('./final_model/final_model_pass80.atmodel')

# %%
contents_index=all_contents_refined['idx']
all_comments_refined = [x for x,idx in zip(merged['comments'],range(len(merged['comments']))) if idx in contents_index]
all_titles_refined = [x for x,idx in zip(merged['titles'],range(len(merged['titles']))) if idx in contents_index]
all_urls_refined = [x for x,idx in zip(merged['urls'],range(len(merged['urls']))) if idx in contents_index]

# %%
topic6_dict=dict()
for i in range(6):
    topic6_dict[i]={'titles':[],
                   'contents':[],
                   'comments':[],
                   'similarity':[],
                   'idx':[]}

# %%
def make_topictable_per_doc(ldamodel, corpus):
    topic_table = pd.DataFrame()

    for i, topic_list in enumerate(ldamodel[corpus]):
        doc = topic_list[0] if ldamodel.per_word_topics else topic_list            
        doc = sorted(doc, key=lambda x: (x[1]), reverse=True)

        for j, (topic_num, prop_topic) in enumerate(doc): 
            if j == 0:  
                topic_table = topic_table.append(pd.Series([int(topic_num), round(prop_topic,4), topic_list]), ignore_index=True)
            else:
                break
    return(topic_table)

# %%
topictable = make_topictable_per_doc(model_saved, corpus)
topictable = topictable.reset_index() 
topictable.columns = ['No_document', 'No_topic', 'similarity', 'detail']

# %%
for idx,row in topictable.iterrows():
    topic6_dict[int(row['No_topic'])]['titles'].append(all_titles_refined[idx])
    topic6_dict[int(row['No_topic'])]['contents'].append(all_contents_refined['contents'][idx])
    topic6_dict[int(row['No_topic'])]['comments'].append(all_comments_refined[idx])
    topic6_dict[int(row['No_topic'])]['similarity'].append(row['similarity'])
    topic6_dict[int(row['No_topic'])]['idx'].append(idx)

# %%
topic6_dict[0]['comments']
# Out:
# [[['"요즘엔 휠체어도 속도내고 빨간불에 지나가고 하더라구요. 그럼 그냥 뛰어다니지 장애인이 무슨 특권도 아니고. 휠체어로 사람치면 그냥 휠체어 몰수하고 지돈으로 사라고 했으면 좋겠다. 젊은 노인들은 휠체어타고 다니고 80노인은 걸어다니고 실제 걷지를 못하는지 제대로된 검증도 필요하다."',
#    '"ㅋㅋㅋㅋㅋㅋㅋㅋㅋ표정 ㅋㅋㅋㅋㅋㅋ"',
#    '"저래서 차에 치이면 100%차주가 피보는거지 드럽운법때문에"',
#    '"장애가 권리고 벼슬인 사람들이 있습니다"',
#    '"수동휠체어에 연결해서 전동휠체어처럼 만들어주는 기기입니다. 대부분 수입이기도하고 장애인들이 이용하는거라 잘 모르시겠지만 10년전에도 있던겁니다. 중국산이 많아 배터리 안정성이나 인증받은 제품이 없을거같네요. 제대로된 전동휠체어는 장애인등록및기준에 합당해야하는데 그 기준에 합당하지않은데 기능장애 있는분들이 주로 씁니다."',
#    '"자동차도 아니고 자전거도 아닌 전동킥보드가 차도에서는 운전자에게 위협이 되고 보도에서는 보행자에게 위협이 된다. 정부는 전동킥보드를 완전 폐지해야 한다"',
#    '"타고다니는건 좋으나 제발 주의살피며 천천히 다녀주세요. 자전거, 전동 킥보드 기타 외 타고다는 것들은 모두 주의해야합니다."',
#    '"점점승용차운전하기힘들어진다"',
#    '"한 변호사님 당황하는 표정ㅋㅋㅋ"',
#    '"장애인전동카트 상당수가 비장애인입니다. 과속은 물론 팔걸이에 여자를 태우기도 하고 자기들 끼리 드리프트도 하고 야간에 도로에서 조명은 커녕 반사판 하나없이 주행하는거 보면 정말 아찔합니다. 지하상가에서 경적울리며 달리기도 하고 아주 개판인데 음주운전까지 하네요..무법천지죠."',
#    '"저런거 차에 치이면 확인 사살 하는게 싸게 먹힌다"',
#    '"전킥 속도제한 풀어서 속도내는 사람 많음"',
#    '"전동 휠체어보다 싸것네"',
#    '"애자들이 저렇게다니는데는 이유가있지.....그러니 휠체어타고다니는거다"',
#    '"한 변호사님 와~우!! ㅋㅋ"',
#    '"오 와우옼..ㅋㅋ"',
#    '"죽어봐야 정신차리지"',
#    '"장애인이 벼슬이냐ㅋㅋ"',
#    '"시속 25km는 저거보다 빠름"',
#    '"딸배 dna 헬센진들 답게 신호무시와 과속은 기본일듯 ㅎㄷ"']],
#  [[]],
#  [['"도데체 킥보드 도입한 정치인이 누구야? 얼마나 받아 먹었길래 문제 투성이인 이상황을 만들고 수습도 않하고 법도 이상하게 만들고,,,, 국민이 봉이네,,, 욕만 나옴,,,, 킥보드 도입한 정치인이 누군지 밝히고 비리를 자행한 자들 싸그리 집어 넣고 싶다"',
#    '"도데체 이걸 왜하는거야... 그냥 니들이 킥보드 사서 타고다녀!"',
#    '"올바른 개인형 이동장치의 문화는 킥보드 업체 니네만의 생각이고 암데나 막 버리고 가는거 즉시 견인 후 과태료를 십만원으로 올려서 세수 확보하고 저 개같은 킥보드 쓰레기 주차 좀 막아보자."']],
#  [['"상식적으로 생각을 해보라고...공익킥보드라는것이 나이드신분들이 이용하는경우가 얼마나 되겠냐고요...보통 20대초반들이 사용을 할껀데 그나이때 준법정신을 갖고 살아온적이 얼마나 되겠냐고요...그러다보니 대충타고 대충놓고 그렇게 살다보니 맨날 문제가되는 뉴스가 나오는거 아니냐고요...답답하다 진짜...."']],
#  [[]],
#  [['"경찰도 배치한다면 찬성 \\n헬멧 미착용, 과속, 두명이상 탑승 등 모든걸 단속할수 있게 경찰을 1킬로 마다 배치한다면 시행하든지"',
#    '"여럿 죽일일있나"',
#    '"세금이 넘쳐나는갑지"',
#    '"센텀 에서 송정까지 주말마다  지옥입니다\\n내년 롯데월드 개장하면 더 힘들듯\\n그것 부터 해결해 주세요"',
#    '"갈맷길로 충분하다...이상한짓 하지마라...이걸로 뭘또 헤쳐먹을라고...형준아 적당히 해라 적당히"',
#    '"이상한 것 좀 만들지 마라"',
#    '"이건 또 자다가 봉창두드리는 소리여? 안전모, 보호장구, 면허등 규제로 킥보드 다 망했는데 누가 탄다고 쓸데없는데 돈들이냐? 어느넘이 바람잡는겨?"',
#    '"BRT만드는것도 차막혀서 빡치는데 탁상행정하는 공무원들은 다 장님인가요? 왜 눈으로 결과 뻔히 보면서 뻘짓만 해대는지"',
#    '"전동킥보드는 이거 분명히 뒤봐주는 놈이 있다. 헬멧안써도 안잡아 애들도 타라고 탑승연령낮춰 갑자기 온 거리에 전동킥보드가 나뒹굴어져 있고 이거 분명히 바다이야기 처럼 머가 구린게 있는게 틀림 없다."',
#    '"동해선 배차간격이나 좀 줄여주십시오. \\n최소10/20은 되야합니다."',
#    '"...시장님 거기에 본인땅이 있다고 너무 막 나가시는군요"',
#    '"시공회사와 구청의 관계부터 의심된다"',
#    '"세금 쓰고 싶어서 환장을 했네. 뻘짓거리 하지말고 제발 하지마라."',
#    '"킥보드는 그냥 도로에서 타게 해라...사람부딪히면 엄한 아이들 노인들 사망할수도 있다...도로에서 차랑부딪히면 킥보드가 날라가겠지"',
#    '"전동 킥보드 충전하다가 폭파사고 난 사람이 접니다\\n위험하고 목숨이 아깝지 않으면 타세요~"',
#    '"부산시민한테 물어봐라 누가 찬성하는지?\\n여기저기 안막히는 도로가 없는데 뭔 뻘짓이야"',
#    '"도로 좁고 사고 위험 너무 높으니 하지 마세요"',
#    '"외지에서 킥보드 타러 걸어서 오나??\\n어쨌던 그사람들이 다 승용차로 올건데 그 많은 차가 또 다른 교통정체...\\n제발 동부산권에 뭘 더 하지마라 진짜로..."',
#    '"또또 씰때없는 짓 한다"',
#    '"제발아무것도하지마세요"'],
#   ['"또 사고치네 해운대구청 사람이 걸어다니는 길에 저걸하면 사건사고 많아지는데. 사람이걷는길은 걸어서 경치좀 보게 하고 그길들은 위험하고 좁으니 전동퀵보드는 더 사고만 키울뿐. 또 인명사고 1호만들지 맙시다. 국공유지 용도변경 이렇게 쉬웠나? 참 !"',
#    '"트레킹 정도만 ~ 가끔 싸이클 하는 몰지각 분들 볼때면 화나는데~ 거기다ㅡ전동  퀵보드~ 좁은  길에 그만좀 합시다!! 전동퀵보드는 넓은 운동장 가서 타세요!! 해운대구에서 무슨 이런 구상을 하나요!! 주민들 시민들은 절대 원치 않소!!"',
#    '"지금도 충분하게 좋은데 멀자꾸 할려는지 쯔쯔할일없나"',
#    '"딸배들 신나게 댕기는거 아님?"',
#    '"진짜 관광을 위해서라면 광안대교위에 킥보드 전용도로를 만들어주세요 대박납니다."',
#    '"또 뇌물받고 LCT처럼 부정부패저지르는건가  답이없다"',
#    '"자전거도  탈수있게 해줘.\\n그전에 동물원부터 어찌 해라.!!!"',
#    '"송정 해수욕장 해변가와 배후를 실리콘 밸리 같은 첨단 업무지구로 만들어야한다 충분히 발전가능성이 있다 해운대도 해변가 주위로 공유오피스가 들어오는등 관광업 이외직군이 발전하고 있다"',
#    '"사고나서 머리깨지고 팔 다리 부러지고 니가 잘못했다 니가 잘했다 뻔한거 아니냐..."',
#    '"박형준 부산시장 뭐하자는 거임??? 😠😠😠😠😠😠😠"',
#    '"전동킥보드 타고나서 아무데나 던져놓지나 마라ㅡㅡ"',
#    '"그냥 자전거도로만 만들어.. 무슨 킥보드야 애들 어른 다친다. 그리고 제발 뻘짓말고 대한민국명소답게 제대로 만들어봐라"',
#    '"남들 사는 동네에 이상한 짓거리 하지말고 할라면 딴데 다 하든가.. 누가봐도 위험하고 사고 발생 높은 걸 왜 할려는지 이해 할 수가 없네.. 뒷돈 받아 쳐 먹었니?"',
#    '"예능 피디만 모아놨냐 ? 세금 어떻게 써야 시민들 웃길지 대가빠리 맞대고 논의중임 !\\n?"',
#    '"효과가 좋겠군요.\\n얼른 추진되길 응원합니다~"',
#    '"퀵보드 사망사고 나올수 있겠네"',
#    '"박 시장 어떻게든 사업 추진해서 뒷돈 챙길려는 ㄷㄷㄷ~ 너의 임기가 1년인게 얼마나 다행인지!"',
#    '"누구 발상이고 당장 퇴사 시켜라!\\n발상자가 킥보드 타고 다닌다고 이딴 아이디어 낸거 같은데\\n걍 세금 월급 받고 엄한지 말고 가만히라도 있어라"',
#    '"부산에 전동킥보드 타는 사람 별로 없는데 뭔소리임 ㅋㅋ 특히 오시리아에서 청사포까지 킥보드 타면 무슨 의미가 있냐 거기는 바다 보면서 천천히 걷는게 딱 좋다"',
#    '"저거 시행하자마자 100% 인명사고 난다."'],
#   ['"상상하기도 싫다"',
#    '"누구머리에서 나온계획이냐....하.."',
#    '"또  쓸데없는  짓거리  하고있네  국민들이  다  누릴수  있는  특별한  산책로라면  모를까  킥보드? 웃기네  웃겨  어느놈  대가리에서  나온  생각인지..."',
#    '"도로좁고 교통량심한데 거기다 킥보드전용도로??? 누구 머리에서 나왔는지 참.,"',
#    '"진짜 민심을 반대로 가네...."',
#    '"사고난다 하지마라"',
#    '"버스전용차선때문에 20분이면가는거리 1시간가는데 자동차문제부터도로를해소해야한다고생각하지않으십니까? \\n참답답하다.."',
#    '"세금가지고 장난치지마라"',
#    '"킥보드사고  몇천건인데  장난하나"',
#    '"킥보드가 위험한데 킥보드 전용도로 참 그렇게 할일이 없는지\\n사고나서 뉴스 나오고 후회하지말고 그냥 운동할수있게 둘레길 식으로 만들어라 대도안하는 쓸데없짓 하지말고"',
#    '"킥보드 만드는 업체가 로비하나?  거지같은 짓 마라  세금으로\\n길닦고..  블럭도 손 보겠지?  휴..  느그들이 선거 때 했던  공약이나 좀 지켜라  쓸데없는 짓 말고.."',
#    '"자전거랑 구조자체가 달라서 전용도로 만들때 이것저것 고려를 많이해야될텐데..."',
#    '"전동킥보드없애라좀"',
#    '"차막혀서댕길수가없다..도로나만들어라..씰때읍는거맹글지말고"',
#    '"롯데아울렛 이케아때문에 도로가 주차장인거 모르냐 도로나 넓혀라"',
#    '"잘 가다가 사진찍는다고 갑자기 끽 서면 뒤따르던 킥라니들 쪼르륵 다 부딫히고 자빠지고 피터지고 난리 함 나봐야 아~~~설치하면 안되는거였구나~~할끼야."',
#    '"완벽한 뻘짓 오시리아관광단지내 스마트모빌리티 특구 예산은 다 날려먹고\\n부산관광 전체계획과는 무관하게 특정기업 놀아난것아닌가 생각됨"',
#    '"찬성합니다"',
#    '"자전거도로좀만들어주세요"',
#    '"ㅋㅋㅋㅋㅋ 박형준 슬 시동거네 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ"'],
#   ['"돈을 왜 그런데 써? 수비오거리쫌 어째 하숑"',
#    '"또 세금낭비할 생각하노ㅋㅋㅋ"',
#    '"세금 낭비그만해"',
#    '"안돼ㅠㅠ"',
#    '"인도는 반으로 줄이겠군"',
#    '"그런데 이런것은 왜 늘 동부산에만 설치를 한다는 것인지..서부산이 더 필요할것 깉은데.."',
#    '"부산은 관광도시 개발을 해야된다~\\n광안대교 케이블카, 황련산 케이블카 만들고!!!\\n인천보다 못한 부산...."',
#    '"언놈 빡 대가리에서 나온거고.\\n진심 패죽이고싶다.\\n쓰잘때기없는거 생각하지말고 맡은 일이나 잘해라."',
#    '"제발하지마라"',
#    '"교통지옥은 포기고? 보여주기식 행정은 이제 그만해라"',
#    '"자전거길도 전동킥보드 위험한데 킥보드전용길에 자전거는 안다니나 사고나서 여러명 황천가겠네  쪼대로해봐라 다치고 빙신되고 죽는넘만 억울할거다"',
#    '"개판되겠네"',
#    '"해운대는 주차할 공간이 많은가배"',
#    '"사람 여럿 죽어나가겠네 ㅋㅋㅋㅋ\'ㅋ"',
#    '"쓸대없는짖 하지말고 도로나 만들어라 쉬파 차밀려서 죽을지경이다. 철길 없애고 일딴 임시도로라도 만들어 평일 주말할거없이 차밀려 죽겠다. 놀이동산 개장하면 어떻게 할거냐?"',
#    '"적당히 해라..."',
#    '"해운대에 주차하고 자전거나 킥보드 갈아타고 동부산으로 쇼핑간다고? 누가 이런 말도 안되는 연구결과를..."',
#    '"아이디어는  갠찮아요   동부산으로 도로 철도가 부족한 상황에서 PM이 무슨소용입니까~"',
#    '"산책로를 만들어야지. 머하는 짓거리야!"',
#    '"차라리 도로를 만들어 .광안대교 옆에 브릿지 해서 정사포로 빼고 거기서 그도로에 연결시켜"'],
#   ['"지랄풍년이네~"',
#    '"미포서 송정까지 해변 걷는길 확장해라 좁다"',
#    '"교통문제 해결???? 납득할수가 없네요"',
#    '"하지마라"',
#    '"안그래도 복잡해서 미어터지는  부산인데 만들때가 어딨노"',
#    '"절벽에서 많이 떨어지겠네"',
#    '"장난하냐?  좁은 도로에 전용버스로 더 길을 좁게 종일 복잡하게 만드는 무지한 행정가들 땜에 살기 힘든 부산을 만들고 있다."',
#    '"여러사람다치겠네 계속규제만늘어가는걸 이제부산에선 발벗고나서네....자전거사고도증가해가는데 킥보드까지사고나라이거지..."',
#    '"어느 업체에 로비 받았는지,"',
#    '"쟐이어주시길"',
#    '"ㅎㄷㄷ"',
#    '"말도 안되는 소리 누구 발상인지 참 한심하네요."',
#    '"BRT 부터 킥보드 도로  돈이 남아돌아서 머리가 돌았냐 왜자꾸 헛지 꺼리만 하냐"',
#    '"정말 부산은 도로가지고 장난 많이 치는구나"',
#    '"기본적인 헬멧 2인탑승도 해결 못하면서 만든다고?세금 아깝다 탁상행정 개.대.가.리 공무원님들아"',
#    '"와 진짜 최악이다. ㅎㅎㅎ"',
#    '"전동킥보드  때문에  그마이 욕쳐먹고  또  ㅈㄹ들이네"',
#    '"하지말지 그냥..."',
#    '"세금을  저렇게  쓰도되나. . .왜   만들려고  하지. . . .희한한 발상이네. . . . ."',
#    '"그냥  하지마   개판된다    예산낭비이다     공무원들아  좀   생각좀  달리해라"'],
#   ['"와 코로나 도로는 않만드나"',
#    '"한심하다...헛웃음나오네ㅎ"',
#    '"이딴거는 도대체 어떤 ㅅ  ㅐㄲ  ㅣ대 ㄱ ㅏㄹ 빡에서 나오는거냐\\n그 ㄷㅐ 갈 빡 구멍내고싶네"',
#    '"하지마라. 그거 관리 안된다. 개판만 되고 결국 예산 낭비가 될뿐일끼다. 그리고 안전사고 계속 일어날껄  마 안하는게 마 답이다"',
#    '"투표잘해라"',
#    '"사고나면 우찌 감당할라고?\\n위험성때문에 점점 사라져가는 퀵보드를 왜?"',
#    '"부산시 수준..  이딴걸 용역주고 받아서는 그걸 또 추진한다고? 그냥 댓글창이나 보고 결정해라. 짜고치는 가잖은 용역에 세금쓰지말고."',
#    '"할짓도 왠간히 없는가보다ᆢ세금쓰고 싶어 환장한 공무원들 다 퇴출시키고 싶다"',
#    '"🐕 💩 같은소리하고 있네.."',
#    '"다 디져라 ..\\n무슨 퀵보드냐 ㅋㅋ\\n지옥 빨리가는 퀵이냐"',
#    '"킥보드 매니아 성현이♡"',
#    '"기장쪽 좀 어떻게 해봐요... ㅠㅠ \\n지금도 주말에 엄청 막히는데 \\n롯데월드 개장하면 주말에 헬임 ㄹㅇ..\\n세금은 이런데 쓰는거여 어류"',
#    '"중국새기들하고 무슨 더러운돈 주고받았길래 전동보드 못팔아서 안달이누? 적당히해라 진짜 국민들은 필요없다고 난린데 왜자꾸 추진하는겨?"',
#    '"전동킥보드는 사회악이다"',
#    '"전동킥보드 도로가 생기면 차량통행에 도ㅡ움이 될것같진 않지만. .  관광객이.전동킥보드를 조금더. .  즐길수는 있겠네. 큰효과는 없겠지만 ㅋ"',
#    '"해운대구에 도로 중간에 버스전용차로... 이거 누구 아이디어냐? 차 막혀죽겠는데, 왜 뻘짓을.... 게다가 밑으로 지하철 지나가는데, 위에다 버스전용차로?? 공무원 얼굴 좀 보자. 누구 아이디어냐? 😡😡😡😡"',
#    '"ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ 오랜만에 웃었다 ㅋㅋ"',
#    '"정신있나... 킥보드끼리 충돌하면 크게 다친다. 간단한 물리학 계산 한번 좀 하고 제발❗❗❗❗몸무게 곱하기 속도 해봐. 그 뉴톤으로 부딪혀봐."',
#    '"사고 날일 있나 하지마"',
#    '"미쳤구나"'],
#   ['"예~~헐~~~\\n그건쫌~~~~"',
#    '"해운대에 차 주차하고 이런거 타고 동부산 가면 교통마비 해소된다고???\\nㅋ농담이 과하구만...ㅋㅋ 더 마비되겠구만..ㅋ\\n달맞이길은 느림보 차 앞에 있음 뒤에 쫙밀려요~\\n중앙선 침범해서 추월해야한다고~ \\n교통체증해소가 아니라 기업들을 위해서 주변 놀거리를 더 만들려는 걸로 보입니다만?"',
#    '"할거면 도로 새로파서해라 기존자동차전용도로에 만들지마라 진짜"',
#    '"헛짓거리 잘하네ㅋㅋ"',
#    '"뭐하러 \\n지금조 OOO 차 졸 밀 리는데"',
#    '"뭐 자살코스냐?"',
#    '"부산시는 참 해운대에 뭐라도 더 하려고 노력하네"',
#    '"헛짓거리 말고  부산에 기업유치하고 \\n일자리 만들어라 부산에 이제 먹고살게없다\\n쫌 헛 돈좀 고만쓰라."',
#    '"진짜 기자가 할일 없는가보네\\n우리는 후손들에게 편리가 아니라 환경을\\n이어주어야하는데 기자라는 양반이 개념도 없는지\\n아니면 우리가 생가하는 진정한 기래기일지\\n의문이 드네요"',
#    '"밥 묵고 그래 할일없나?"',
#    '"지랄 킥보드는 출입금지 거긴 걷기좋은곳으로  유지해야한다"',
#    '"진짜 쓸데없는 짓거리한다"',
#    '"참 별의별 개뻘짓거리를 버스전용차선부터해가 아주 시민을 위하는거처럼 옘병 개질알뼝들을 다한다 진짜 전동킥보드 위험하다고 타지말자는 식인거 같은데 전용도로? 장난하나"',
#    '"미친 부산시장아."',
#    '"길 만들기 전에 안전법규부터 좀 만들면 안되겠니? 보고 있으면 아슬아슬하다"',
#    '"내년3월이후 기장은 주말에 얼씬도 안해야지"',
#    '"철도나 다시 깔아라 해안 철도"',
#    '"개소리ㅋㅋㅋ 부산 심각하다!ㅋㅋㅋ"',
#    '"하는 짓이 문재인스럽네"',
#    '"뭔 헛 짓거리 냐"'],
#   ['"지랄들~"',
#    '"ㅋㅋㅋㅋㅋㅋ진짜ㅈㄹ도 가지가지로 한다ㅋㅋ"',
#    '"할께천진데 지금 머하자는거?"',
#    '"저기서 튀어나오는 킥보드같은건 벌금 천만원씩때너버려라"',
#    '"오거돈때는 여비서 치마속만 관심가지다가 이제 좀 시청이 일을하는것 같네."',
#    '"자전거 도로도 제대로 못 만들어 놓고 무슨 또 이상한 일을 하려고 하는건지...에휴..."',
#    '"지.랄하지말고 송정터널  이거 해결이나해라 쓰붕 지옥이다"',
#    '"인구가 없어. 때리치워..세금낭비야.. 남은 사람은 전부5060인데 이사람들이 이걸 탈거같니.. 생각 좀 해라."',
#    '"지금도 인도에너 무법천지로 돌아다니면 보행인한테 위협을 가하는데"',
#    '"업체로부터 로비 받았나"',
#    '"자전거 전용도로가 없나 ? 왜 그리 전동킥보드 전용도로 만들려고 하나 ~? 부산시 예산이 많은가보지 ??"',
#    '"쓸데없는데 세금 낭비하지 마라.. 그리고 너무 위험하다.. 왜 돈을 못써서 안달이지? 도대체 누구 머리에서 나온 발상이지?  누구 머리에서 나온지 모르지만 니들 자식들이 타고 다닌다 생각해라 글면 답이 나올꺼다.."',
#    '"전동킥보드는 없애 버려야"',
#    '"뻘짓고만하고 지하철2호선이나 연장하자......\\n그리고 풍경열차 오시리아관광단지까지 연장하고\\n트램으로 바꾸자...."',
#    '"난 완전 반댈세. 그냥 산책로로 합시다."',
#    '"지금도 걸어다니는 사람들 비좁은데 그걸 또 길을 낸다고? 제정신인가"',
#    '"그냥 동부산 가는 자동차 전용 길이나 하나 더 만들어라 출퇴근 주말마다 차 겁나 막혀서 스트레스받는다"',
#    '"만들지마세요. 돈쓸데가 그렇게없나요"',
#    '"전동킥보드도 번호판달았으면 좋겠다 와리가리치는것들 그냥 밀어버리고싶거든. 오토바이도 욧같은데 킥보드도 욧같다. 정상적으로타면 정신에 무리가 오는건가???"',
#    '"고마놔둬라.. 가뜩이나 비좁은데 먼 전동킥보드여... 거기쓸돈 불우이웃에 써라 차라리.."'],
#   ['"킥보드 도로가 생긴다먼  차량  보다  킥보드 이옹자가 많이 생길꺼라  생각들며  차량 수가 좀 줄어 들지 않을까여?   뭐  약간의  미묘한  차이가 있을수 있으나 기존 도시정비의 도로 개편 문제점을  먼저  세심히  들여다 봐야 겠습니다.  ."']],
#  [[]],
#  [['"뻘짓하고 앉아있네....\\n지하철2호선 연장이나 하자......."', '"좋기는 한데…"']],
#  [['"없애란말이다"',
#    '"없애는게 옳다는 생각입니다. 이유는 충분합니다."',
#    '"뭘 어디로 다녀 ㅋㅋ 그냥 다니지마 ㅋㅋㅋ"',
#    '"옛날에는 인도와 차도의 구분도 없었습니다. 마차가 등장하기 시작하면서 사람과 충돌사고가 늘어나자 이를 구분하기 시작했지요. 이동수단이 점점 진화하고 다양해지는 만큼 도로도 계속 변화해 나가는 것이 올바른 것이 아닌가 생각됩니다."',
#    '"전동킥보드  때문에  미치긋다  차도로  다니고 사고날뻔하고 면허?  웃기지마셔  면허없는애들이  더많이 타고다닌다 경찰들은 단속도  안하고\\n사고날뻔한게  한두번이냐"',
#    '"1. 없애라\\n2. 없애라\\n3. 없애라\\n4. 없애라\\n5. 없애라"',
#    '"타지 말란 소리다"',
#    '"국민이 킥보드를  원한적없고~!!! 중국먹여 살리는모든 사업에  깨국민들은 분노하고 죄다  파기 하길 원한다~!!! 도로는 차가 다니는곳이고~!!! 인도는 사람이 다니는곳이다 ㅡㅡ"',
#    '"애들 난리도아니다. 퀵보드 한개에 3명씩도탐 환장한다"',
#    '"솔직히 자전거보다 위험함. 바퀴도작은데 무게중심도 위쪽이라 애기들타는 킥보드로생각하면안됨. 패인거 못보고밟으면 바로자빠짐."',
#    '"애시당초 이런걸 자동차가 다니는 일반도로에서 허용한 거 자체가 잘못이다. 실제 도로에서 헬맷쓴다고 안전하나? 자동차안에 있는 사람도 사고나면 중상 혹은 사망인데...누구의 아이디어인지...그냥 죽으라는 얘기."',
#    '"위험한거 알면서 왜타는거냐 진짜. 보행자도 운전자도 본인도 위험한걸 도대체 왜....  도로의암덩어리다"',
#    '"제발좀 치워라!!!"',
#    '"킥보드는 백해무익이다."',
#    '"운전하다보면, 죽이고 싶은 욕망이 마구 생긴다. 제발 내가 정신줄 놓치 않기를..."',
#    '"없애는게 답이다"',
#    '"킥보드를 자전거보다 느린 시속 10키로이하로 세팅하는 강제법을 만드는게 유일한 답임."',
#    '"킥보드 없애면 됩니다. 왜 필요한건지 정말 이해안되네요"',
#    '"전동킥보드는 사라져야 할 물건이다. 각종 사고유발 물건!!!!"',
#    '"인도에 오토바이도 모자라서 킥보드까지..이용후엔 아무데나 방치하고~도대체 누가 이런걸 허가해준건지.."'],
#   ['"애초에 오토바이를 탄다고 생각하고 타야함."',
#    '"전통퀵보드 공유를 없애고 일반인은 차량처럼 번호판 달고 안전장치 하고 다니게 해라 무분별하게 타고 다니는 애들이 문제지 벌금 물려봐라 그러나"',
#    '"정작 국민들은 킥보드에 대한 반대가 심한데..왜 지자체는 계속 운영할까...뒷 돈 때문에 구린건가?"',
#    '"킥라니들.싹다 치워야해"',
#    '"퀵라니들 개극혐... 딸배보다 더 위험함.. 왜냐하면 퀵라니들은 지들이 뭔잘못한지도 모르고 개같이 운전함.."',
#    '"혼란과 보행자 안전에 위협............."',
#    '"그냥 타지 말라고...\\n킥라니 사고 엄청난데 여전히 법 무시하고 무면허,2명탑승,역주행,자동차전용도로 이용,무단횡단...사고유발은 킥라니들이 해놓고 가해자로 몰라는 차 운전자들이 대다수임.\\n킥라니 = 민폐 라고 보는게 현실임.\\n공유전동킥보드봐라.아무 곳이나 버리고 가서 통행에 방해주고 사고유발하는데 아무도 책임 안 지잖아.\\n근데 뭘 따로 만들겠냐.\\n있는 법도 안 지키는데 없애는게 답이지."',
#    '"싹다수거해서 벌여라 시민들호주머니에서 돈뜻지말고"',
#    '"이것도 moon 무능정부의 탁상공론...ㅉㅉㅉ"',
#    '"타지마 그냥. 암적인 존재다."',
#    '"킥보드 허가해준 사람 조치해야된다."',
#    '"타지마라 셀프로 넘어지는것들"',
#    '"안타면되잖아 여자애들 정신사납게 다니는거 보면 위험천만함 주차도 아무대나 해놓고"',
#    '"그냥다니지마...없애라.제발"',
#    '"저 퀵보드 좀 없앴으면"',
#    '"모두에게 고통! 골목 여기저기 널부러져있는 쓰레기 같은 존재! 허가해준사람 처벌해라!"',
#    '"저게 면허가 있냐? 보험이 되냐? 왜 차도로 기어나오냐고? 타다 다리 중간에 놓고가고, 술먹고 타고, 갑자기 밤에 도로주행하고 개판인데 대체 어떻게 관리하려고 도로를 허용하냐?"',
#    '"킥보드자체가 문제원인\\n없어지면 해결 끝"',
#    '"도로로 못다니게 해라..차도는 물론 인도,골목길도 못다니게 해야한다.그건 이동수단이라기보다~흉물이다."',
#    '"없애라 요즘 대중교통 잘 되어 있다.\\n쓰잘때기없이 교통체증 만들지 말고..."'],
#   ['"10년내 석유차 퇴출되면 모든 자동차 전기 수소로 바뀌고 그에맞는 유로 안전기준 적용하면서 지금처럼 천만원대 저렴한차 없어질거임   가난한사람, 사회초년생은 차 못타는시대가 오고있고 어떻게보면 일본의 자전거문화처럼 pm 전동탈것이 자리잡게될듯 다들 무조건 반대만하는데 앞으로 10년은 일본의 잃어버린 세월처럼 가난해지는 시간임  돈없으면 다들 싫어도 자전거든 전동킥보드던 자동차대신 타는시기가 올것"',
#    '"만들면 그길로만 다닐거라고봐?"',
#    '"길을 만든다고 그 길로만 다닐거라고 생각해? 누가? 그리고 킥보드는 타는 사람만 타지. 걸어다녀라 쫌."',
#    '"제대로 된 법을 만든 다음에 도입을 하세요!\\n헬맷도 안 쓰고  난폭운전 하는사람들 많이 봤습니다!!\\n차로 칠까 무섭다 무서워!!!"',
#    '"퀵보드는 없애야 합니다. 관리 하지도 못할 일들만 자꾸 허가내주는데 이게 도대체 누구를 위한 건지"',
#    '"전동 키보드가 얼마나 민폐인걸 아나 운전지식도 없고 막 역주행에 보행자까지 다치고 정말 싫다 그리고 사망사고도 많고 우리나라는 왜 이렇게 무책임하게 허가해주냐 도로나 기타 주행할수 있는 부분이 하나도 준비도 안되어 있는데 정부는 그냥 돈만 생각하고 허가 내주냐 킥라니 밤에 운전할때 도로에서 역주행에 헬멧도 없고 잘 보이지도 않아 죽을라고 노력하는걸로 보임 그리고 자동차 운전자는 평생 트라우마 ㅡㅡ 그냥 공원용으로 하라 해외처럼 전용 도로 만들때 까지"',
#    '"국민들 혈세 낭비하지말고 공용킥보드, 공용자전거는 다 없애요. 나라빚이 올해에 1000조가 넘었던데."',
#    '"차도위에선 교통사고 유발하고 보도위에선 보행자위협하고 타고다니다 아무데나 방치하는데 없애라 헛돈쓰지말고 ㅡㅡ"',
#    '"지금 도로 다니다 보면 인도 곳곳 차도곳곳  방치된 전동보드 넘쳐난다  좀 없애라 가끔 운전하다가 찻길 커브에 있는데 확 밀어버리고싶은데 내차 망가질까봐 참는다 어디 망치로 확 다 때려부서버리고싶다 ㅡㅡ^"',
#    '"인도나 잘 만들어줬으면 좋겠다."',
#    '"타고 싶으면 규정을 제대로 준수하던가.. 헬멧도 안 쓰고 2명씩 같이타고... 단속,관리도 안 하고...\\n\\n배달오토바이보다 더 개판인 킥보드... 이럴거면 없애던가..."',
#    '"한국에 왜 저게필요하지? 대중교통이 잘되있는 나라인데. 저거왜 쓰는거야?  장애인이야?"',
#    '"없애는게 답이죠..  ㅋㅋ"',
#    '"100년 전에 발명되었던 전동킥보드가 도로에서 사라진 이유를 생각하면 답이 나오지 않을까요?\\n그냥 없애면 됩니다."',
#    '"헬조선에만 있는 킥보드 규제 ㅋㅋㅋ"',
#    '"너무 빨리 달려서 위험해요. 없애주세요"',
#    '"자전거도로를 독일 베를린처럼 바꾸란 말이다. 기존차로 하나 없애는 방식으로 하고 킥보드 전용 좌회전 신호 만들어주면 되는걸"',
#    '"인도로 다니도록 (말도 같이 타고다니던 시절에 만든)구닥다리 법을 개정하는게 맞죠. 차와 킥보드가 박았을 때, 사람과 킥보드가 박았을 때 비교해보면 어떤게 더 위험하고 치명적인 사고가 많을까요? 전동킥보드 중량이라고 해봐야 20kg 이내이고 불법개조만 작살을 내놓으면 크게 위험하지도 않음. 속도만 25내외로 제한하고 앞만 보고 주의해서 운전하면 전동휠체어랑 비교를 해도(중량100kg에 육박하고, 속도제한 15km/h) 보행자에게 더 위험하다고 보기도 힘듭니다. 자빠지면 탄 본인만 다치면 되는 문제죠."',
#    '"킥보드 없애고, 자전거도 출근길에 자동차도로 대놓고 다니는 것 없애고, 배달 오토바이 비상등키고 횡단보도 역주행하는것도 없애고 다 없애야 합니다. 운전자도 운전막하고 칼치기하는 것 다 없애고 벌금 100만원씩 때려야 해요."',
#    '"🐕 개 🌿 풀 뜯어먹는소리 하지말고 \\n공유킥보드, 자전거 없애라..\\n인도에 도로에 라누데나 벙치해서 사고유발하고 업체는 책임도, 란전도 내팽시치고 돈벌이만 혈안이다.."'],
#   ['"다른거 다 제껴두고 시민의식만 높아져도 훨씬 좋아질 것 같아요\\n좁은 인도 한가운데에 방해물 마냥 세워놓고 지하철 출입구 주변에 방해물처럼 기본 서너대 이상이 널부러져 있고 신호대기장소에도 지나다니는 행인들 생각은 안하고 그냥 막 놔두고 아주 큰 골칫거리 에요"',
#    '"그냥 없애면됨"',
#    '"다니지마란말이다"',
#    '"이거 없애 주세요. 아이들 다니는 단지안에서 너무 위험해 보여요."',
#    '"도대체누가 저런걸 만들었냐고ᆢ  진짜 운전하다보면등골이  오싹한다"',
#    '"이용자는 미성년자부터 다양한데\\n법적인 책임은 하나도 안지면서\\n도로 인도를 다니는건 되고???"',
#    '"도대체 그렇잖아도 정신없이 복잡한데 저걸 왜 타고 다니냐?? 타고 싶으면 넓은 공터에서나 타고 놀아라"',
#    '"타지마세요. 속도감에 사람들 공포에떨고 아이들이 걸어다니지  못합니다"',
#    '"그냥 타지마 민폐잖아"',
#    '"그냥 타지 마라..없을땐 기어다녔냐고 ㅡㅡ 죽고싶음 도로로 뛰어나와라 차라리 죽는게 나을수도..재수없음 평생 떵오줌 싸며 목에 호스 끼운다..목숨은 하나다 이번생에 건강하게 오래살다 가자 100년도 못사는데 그래도 정~~죽고싶음 조용히 혼자 가라."',
#    '"도교법이 문제가 아니다. 자전거도로나 인도도 문제될게 없지않나. 수조씩 들여 만들고 겨우 정착해가는데 웬 몸으로 부딪힐려고 덤비나. 덤프나 버스와 추돌사고 나봐야 없야겠나? 좀 생각 좀 하고 도입해라. 땅덩어리도 좁은데 현실을 전혀 고려 안한 정책이다."',
#    '"도로  맨 우측  차선으로  타고  가야되는데  거기에는  꼭  불법주차  차량이  길을막고  있지"',
#    '"걍 전부 소각시키면 됨"',
#    '"없애라"',
#    '"그냥 타지마세요 나도 타봤는데 나도 위험하지만 다른사람 민폐입니다 시대를 잘못 타고 나온 기술입니다"',
#    '"전동킥보드 민폐덩어리, 암적인 존재다 제발 없애라"',
#    '"다니지 말고 없애"',
#    '"pm을 이용해야 하는 권리가 있음? 그냥 다 금지시키면 돼지... 어차피 다 중국업체들인데... 태양광하고ㅠ똑같음... 우리 국민들 희생해서 중국 배 불리는 거지... 800미터 걸어다니면 큰일 나냐?"',
#    '"자전거도로 만들려면 예산들지? 차도로 자전거 킥보드\\n다닐수있는거 모르는 카트라이더로 면허 딴게 아닌가 의심되는 인간들 칼치기하고 위협운전하는데 금융치료 개오지게 먹여봐라 돈 아까워서라도 피해다니지 ㅋㅋ 미국만해도 2미터이상 떨어져서 추월안하면 바로 벌금인데 차라니놈들도 문제가 많음"',
#    '"다니지마. 뭔데."'],
#   ['"타지마"',
#    '"킥보드 타는사람들 주차좀 잘해놔라  아무데나 세워놔서 지나다가 불편할때가 종종  타인을 생각해서 배려좀 생각"',
#    '"타지 말고 없애란 말이지!"',
#    '"운동삼아 걸어다녀"',
#    '"개매너가진 놈들이 많은 나라에서 법 제정도 하기전에 저런걸 허가해 놓으니 개판이다 개판이야"',
#    '"없애면된다. 교통법도 모르는 돌대가리들은 \\n대중교통 이용해라"',
#    '"오토바이보다 더 이항하게 타는 놈들도 많더만"',
#    '"없세라  킥보드헬멧도안쓰고  마구자비세워두는 \\n피인간들많다  벌금 물어라"',
#    '"하늘로 다녀ㅋ 백투더퓨처 요새 애들은 모르나?"',
#    '"이명박 같으면 벌써 도로 뒤집어서 킥보드 전용도로 만든다고 20조를 쳐바를텐데..."',
#    '"공유킥보드가 산업에 미치는 좋은점이 도대체 뭔가?...죄다 중국산 사다가 프랜차이즈 본점 차리고 대리점 모집해서 영업하는데?...얼마나 받았는지 열배 줄테니 공유킥보드  없애라 공무원,정치인들아...그게 싫으면 불법주차,불법운전 단속 강화 및 철저한 과태료 및 보행자 하고, 운전자 보호 대책 내놓아라."',
#    '"자전거도로와 같이 써야지~~ 자전거속도랑 일반적인 퀵보드속도가 비슷한데~~ 퀵보드 웬만한건 최고속도 30을 넘지 않는다~ 퀵보드랑 자전거랑 같이 자전거도로를 이용하면된다~"',
#    '"킥보드 너무 위험해"',
#    '"어쩌라고? 문제 지적만 하고 대안은 없어"',
#    '"자전거가 지나가면 그러려니 킥보드는 그냥 거슬림ㅋㅋㅋ근데 불법주정차 택시는 더 18같음ㅋㅋㅋ최악중의 최악"',
#    '"끝차로 죽음의길이다 불법주차 버스정차 택시정차 죽을라면 법규직혀라"',
#    '"공유킥보드 뺑소니는 끊이지않는데 방치해두네"',
#    '"걍 20km 정도로 속도제한 걸어놓고 인도쪽으로 다니게 하면 안됨? 20km 정도면 다치더라도 생명이 위독하거나 심하게 다치진 않을 건데 차로로 내모는 건 너무 위험해보임...차로로 내몰거면 차라리 속도 제한을 풀던가"',
#    '"없애야 함 위험성이 너무 높음 혼자 자빠지고 자꾸 돈 내놓으라는 자해공갈도 너무 많음"',
#    '"위험하니까 타지마!!!\\n안타면 될일을... 오토바이보다 더 위험한게 킥보드다... 빠르고 안전장치없고 \\n법으로 없애버리든가 해야지..."'],
#   ['"만들지도 말고 타지도 마! 얼쩡대서 짜증나니까!"',
#    '"누군가에겐 필요하겠지만 사회전체적으로는 악이니까 필요악은 없애야 마땅하다."',
#    '"아니 애초에 왜 저딴걸 만드냐고 -_-"',
#    '"시속 키로 낮쳐  인도로 다녀라 도로는 넘 위험하다"',
#    '"왕복8차선도로에서 신호위반하며 달리는 킥보드보고 두눈을 의심했었지."',
#    '"틀니 딱 딱이 들은 안타고 다니니 없애라는 말만 찍찍 내뱉쥬... 같이 공생할 생각은안하구.. \\n해결방법을 모색해야지 지들 눈에 안좋아보인다고 일차원적 생각으로 없애라는 말만 해대면 될까요? ㅎㅎ"',
#    '"그래서 신호위반하고 역주행하고 다니는거야?"',
#    '"퀵보도 타게 하려면 새금도 징수해라. 취등록세 받고"',
#    '"타지말고 걸어다녀 이것들아. 운전하거나 인도 걷다보면 짜증난다"',
#    '"킥보드 없애야 한다..인도로 쌩~~"',
#    '"거리를 생각지 않고 나왔으니 여기도 저기도 갈대가 없지\\n거기다 타는 인간들은 하나같이 개념들도 없으니.."',
#    '"킥보드 타는 사람들은 예의가 없다. 타구서 아무대나 내팽겨쳐 놓고...적반하장도 유뷴수지 \\n 어디로 다니냐고 대드네..."',
#    '"밤에 인도에서 다니면, 여기 저기 불쑥 튀어 나온다.. 어떤 것들은 라이트도 안 키고 다녀.. 그러다 사람하고 부딪히면, 쌩가고 간다..ㅋㅋㅋ 정말 욱 하는게 한 두번이 아니다. 인도가 이젠 인도가 아니야.. 자전거 불쑥 튀어 나오지.킥보드 튀어 나오지.."',
#    '"킥보드는 1차선으로 다니세요."',
#    '"걷는게 건강에 좋단다"',
#    '"불만이면 타지 마. 킥보드 없어도 사는데 문제 있어?"',
#    '"도로에서 자동차 옆에 다니면 무섭지 너네도? 인도에서 킥보드 다니면 똑같이 보행자는 위협적임.  교통수단은 사용자가 컨트롤 할 수 있을 만큼만 속도도 내고 거리도 두어 안전하게 타야 하는데 킥보드 저건 돌발상황에 안전하게 멈출수나 있음? 그렇다고 쓰고 나면 걸리적거리지 않게 잘 놓기라도 하던가."',
#    '"킥라니들은 없어져야돼"',
#    '"굳이 좁은 땅에 거지같은 도로환경에 퀵보드가 필요하냐? 기본적으로 아스팔트공사는 겨울에해서 봄여름만되면 누더기에 홀생기는건다반사인도로에 다니라고? 보도블럭은 그렇다고 평평하길하냐? 왜 타냐고  역주랭하는 오토바이 자전거로도 충분하고만...."',
#    '"헬멧?쓰고다니는인간 본적이없다. 두명은기본이고 세놈도타고다니는거봤다.\\n타다가다쳐서 여러사람피해주는니 법으로 못타게해라. 전과자 양성하지말아라.이빌어먹을정부야"'],
#   ['"타지마"',
#    '"정신없는것들이 인도에서 둘이 킥보드하나타다 나랑 애기 칠뻔했는데 좋다고 계속쌩쌩타고다닌던데"',
#    '"오두방구는 인도로 다니는데 킥보드만 단속?"',
#    '"면허 없는 아이들이 자주 타고 다니는 것만 봐도 얼마나 관리가 허술한지 알 수 있다. 대놓고 무면허운전 ㅋㅋ"',
#    '"자전거도 똑같애. 도로로 달려야 하는데 도로나가면 차들이 왜 알짱거리냐 하고, 보도 올라가면 불법이고. 이런 나라에서 뭔 탄소중립은.."',
#    '"원하는 사람보다 원치 않는 사람이 훨씬 많은데 이거 왜 계속 하나..특히 서울은 동네마다 마을버스,따릉이 다 있는데 굳이 이걸 왜...아무데나 세워둬서 시각장애인분들  다치는거 보니까 이건 정말 때려치워야 마땅한 사업임을 다시 한번 느낌!!!"',
#    '"적어도 인도는 아니지 ㅋㅋ차도가 맞지 전동인데~ 자전거도 차도가 맞는데"',
#    '"이렇게 킥보드는 역사속으로 사라지고...옛날에 휠리스 도 그렇지 않았나 잠깐 유행했다 사라질뿐이다"',
#    '"PM없애라."',
#    '"이런  무지한 기래기봤나 현장을 제대로 보지않고 기사를쓰냐 ? 거의가\\n 인도를 비집고 다니잖아 또 인도 아무데나 버려 통행에 지장을주고...이런 괴물을 허가해준 놈이 누구냐 --"',
#    '"타지말란 말이지.. 다니긴 어디로 다녀..."',
#    '"다필요읍고 타고 다니는 인간들 답나오잔아요  그런애들위해서 놔둘필요읍고 길거리 아무데나 버리는인간들 딱알잔아요 말안해도   그런인간들위해서 필요하다면 없애야죠  주관 뚜렷해야 된다고  흉내내는  인간들"',
#    '"공원에서나 타. 차도나 인도 나오지말고."',
#    '"모두에게 위험한 존재다"',
#    '"타지말라구요!!  본인 편하자고 다른사람들한테피해줍니까?"',
#    '"차도로 다녀야지...;; 다닐때가 왜 없나요? 인도는 보행자를 위한거죠. 그게 싫으면 타고 다니지 말아야죠"',
#    '"공유킥보드좀 사라졌음좋겠다.."',
#    '"전용도로를 새로 만드는 수 밖에... 도로로 다녀야하는게 합법인걸 알아서 갓길로 다니는 킥보드들 보면서 대다수의 운전자가 욕지거리하거나 혀끌끌 찬다. 인식수준 바닥이란거지 ㅎ"',
#    '"기함급 사서 헬멧 오지게 눌러쓰고 차랑 맞춰다니면 안위험해요. 공유킥보드가 문제지"',
#    '"없애라는거지 바보야"'],
#   ['"지들도  죽기는 싫어서  차도로 안다니면서 왜 인도에서 쌩쌩 달리냐?"',
#    '"그냥 친환경 교통수단만 도로에 다닐 수 있게 하고,, 모든 엔진자동차들은 법적으로 도로에 못다니게 금지시키면 좋을듯"',
#    '"규정과 도로를 확보하지 않고 무식하고 무능한 관계자들의 생각없는 결과물 이다"',
#    '"우리나라는 ‘공유자산’ 이거 안 맞아. 무조건 자기 소유여야 ‘관리’란 걸 시작해. 당장 출근길에도 아무데나 패대기쳐진 킥보드 많이들 보잖아? 차운전에도 걸리적, 걷는데도 걸리적.. 킥보드가 문제가 아니라 후진 국민성이 문제다."',
#    '"걸어다녀라 ㅋㅋㅋ 걸어다니기 귀찮다고 굳이 킥보드 타고 다니냐."',
#    '"우리나라가 외국처럼 가차선을 만들면 차들이 주차장으로 활용할 걸"',
#    '"아예 킥보드 법적으로 금지했으면!"',
#    '"아주~느리게 \\n 사람보다 쪼끔 빠르게 하면 인도를 가든 차도를가든 상관 없겠지?"',
#    '"고물상이지"',
#    '"타지마"',
#    '"그냥 걸어"',
#    '"없애라"',
#    '"대안은 무슨 !! 미쳤나 합법적으로 킥라니 돌아다니라고? \\n정신 오백년나간소리하고앉았네  그냥 없어지는게 답이고 평화다 \\n킥라니가 달려들고나서도 니주둥이에서 \\"대안\\"이란 말이 나오나보자 !!!!!!!!"',
#    '"민폐  아파트단지에 막세워두고  도로변에 내동댕이쳐두구\\n없애라 답이다 불법으로 지정바람"',
#    '"없애든가, 사고시 비보호제를 운영해라. 모든건 자기 책임으로 해야 안전하게 탈거다."',
#    '"자전거도로만 통행하도록 해라\\n\\n그리고 오토바이 자동차  소음규제좀해라\\n너무시끄러워  오토바이건  자동차건\\n마우라 개조하면 벌금 때리고 압수해라"',
#    '"킥보드 없애라 개넘의 정치인들아!"',
#    '"왜타? 여러사람  위험하게"',
#    '"보도.도로 잘 타고 다니드만~"',
#    '"킥보드 없애라. 킥라니나 운전자나 한순간에 둘 다 인생 조진다"'],
#   ['"타지마라고"',
#    '"없애든가 갯벌에서만 탈수있게 해라"',
#    '"타지말라는거를 못알아듣고 땡깡"',
#    '"킥보드 도입 누가한거냐? 골치덩어리 킥보드"',
#    '"다니지마"',
#    '"어디로다니긴 뭘 어디로 다녀\\n교통사고 유발자들\\n전동 퀵보드 타지마 ㅡㅡ"',
#    '"타지마...다치면 너만 손해야..차량운전자에겐 민폐고..."',
#    '"대깨문정부에서 돈 탈세할려고 만든 지침임 동네에 킥보드 몇만대 뿌리고 세금으로 탈세한거 다 안다"',
#    '"다니지 말라고~~  거실에서  타라"',
#    '"마부작침...  도끼를 갈아서 바늘을 만든다. 이 사자성어랑  기사내용과 무슨관련이 있는지. ."',
#    '"없애라"',
#    '"저전거 전용도로가 있어도그곳을 보행자들이 다니는 곳도 적지 않음.  그것도 2~3명이 나란히 다차지하고."',
#    '"타지마~~~위함해~~~"',
#    '"천천히나 다니길. 헬멧도 안쓰고 다니면서.. 심지어 둘이 타고... 보행자 위협하는 것도 아니고 바짝 옆으로 쌩쌩..  등하교 시 어린이들 놀래는 게 하루이틀이 아님. 깜놀 하고 보면 이미 저멀리... 완전 빡침"',
#    '"관리도 안되고 위험함"',
#    '"없애라...."',
#    '"옳소"',
#    '"안타면된다"',
#    '"면허없음 타지 마라고 해놓고는 면허있는 사람이 몇이나 된다고 저걸 왜 길에다 세워두는지 진짜 이해가 안감 중고등학생 타고 다니는데 도로에서 왔다갔다 묘기하더라!"',
#    '"다니지 말라고.."'],
#   ['"우리나라같이 좁아터지고 자전거 킥보드 무시하는 정서를 가진 나라에선 현실적으로 어려움. 그냥 포기하는게..."',
#    '"지 죽고 싶어서 타는데..뭐..운전자 법 개정이 필요하지..법이 엿같으니.."',
#    '"타고 싶으면 자동차세처럼 세금을내고 말해^_^"',
#    '"그냥 다니지 마라"',
#    '"다니지말라는거지"',
#    '"진짜 짜증나니 타지 말라고, 누가 그런거 허가를 내 주었는지...pm 이 우리나라 실정에 맞냐?? 등신들 하여간 정책하는 것들은 도대체 어디서 뭘 보고 하는지"',
#    '"인도지"',
#    '"부천시는 더함. 유치원 어린이집 초등학교 있는 인도에 자건거도로를 만들어서 인도를 반으로 줄이고 시각장애인 유도선하고 사람이 다닐수 있는 인도가 나머지 반임. 자전거가 다닐수 있는 곳이 적은건 알지만 그렇다고 유치원생 초등생이 다니는 길을 이런식으로 만드는건 아니라고 봅니다."',
#    '"애들 좁은 통학로에 다 세워둬서 사람들 걸어가니기 너무 불편해요. 등교길 주차는 못하게 하고 전동 킥보드는 수도 없이 세워져 있어요. 킥보드 타는 사람보다 안타은 사람이 너무 위험하고 불편하니 다 없앱시다."',
#    '"와 오늘 우회전 해야하는데 도로에 우회전 못하게 킥라니 한마리 폰 쳐다보고있어서 비키라고 경적 작게울렸는데 쓱 쳐다만 보고 길막. 다시한번 뽁 했는데 또 쳐다보더니 길막 다시 뽁 했더니 그땐 노려봄. 진짜 짜증나서 아예 빵 했더니 그제서야 도로에서 물러남. 우깜빡이 켜고있었는데 면허가 있는 자였더라면 내가 왜 뽁 했는지 알았을거다. 머리에 뚝배기도 안쓰고 자동차 통행 방해하고 아 진짜 무면허 킥라니들 극혐이다. 그걸타고 인도로 다니면서 사람치겠다는 생각. 도로로 다니면 차에 치이겠다는 그 간단한 생각이 안드나?"',
#    '"자전거도로  만들려면ㅡ담장높이 허리까지  울타리  만들어서  차도로  분별  확실히  한 후에 허가를  하셨요ㅡ 차들도 안전하게  운행할수  있게요ㅡ 킥보도 자전거  모두다  안전 운전  할수  있도록  만들고  난후에 허가  하시길  바랍니다ㅡ"',
#    '"자전거도로 정비 좀 어떻게 좀 해라 진짜...어디는 있고 어디는 없고...자전거 도로 타고 가다가 보면 사라지는 자전거도로..의구...뭘 제대로 하는게 하나도 없노"',
#    '"안타는게 맞다"',
#    '"인도에서 쌩쌩달리는 킥보드..없애자"',
#    '"https://www1.president.go.kr/petitions/Temp/5CEQLt\\n\\n킥보드 반대 청원해주세여"',
#    '"지금 이 시대에 나와서는 안 될 물건. 가뜩이나 딸배, 자라니들도 넘쳐 나는데."',
#    '"본인도 도로 위에서 위험한걸 알면서 저 위험한걸 궂이 타겠다고... 가다가 넘어지기라도 하면   옆에 지나가던 운전자가 독박"',
#    '"킥보드는 공원에서나 타라~~  운전진 민폐 주지말고~~"',
#    '"전동 킥보드를없애라. 인도도 도로도 다 좁은 나라에서 애시당초 안맞는 발상이라니까????"',
#    '"다니지 말란 소리다 눈치 좀 챙겨라"'],
#   ['"타지를 마란소리다"',
#    '"돈 벌려고 상황에도 안맞는 거 팔고 있는데 세금 몽창들여 기업 돈 벌게 해줘야 되나???? 이게 기자야 회사홍보맨이냐?"',
#    '"다른 건 그렇다 치고 인도서 걷다가 킥보드한테 뺑소니 사고 저처럼 당해보면 무슨 말을 해야 할 지 알게 될 겁니다."',
#    '"타지마 타지말라고"',
#    '"인프라 구축해줄 생각없으면 저거 다 없애든지 속도 자전거수준으로 낮추는 법안을 만들어라"',
#    '"세종은 빈땅에 계획도시로 설계한 게 이따위냐? 인도, 자전거도로 아무 생각없이 줄만 쳐놓고 온갖 방해구조물  다 늘어놓은 데다가 곳곳에 차 튀어나오는 주차장 입출구... 이젠 공용자전거에 킥보드까지 늘어만 놓아 길 다 막아놓고 수시로 공사장비들 도로 무단점거."',
#    '"타지 말라고~~"',
#    '"없애는게 맞는거지 아니면 전용도로 만들고 어기면 철저히 단속하던가 두놈씩 타는것들도"',
#    '"인구 과밀한 도시에서 허가를 해준다는게 말이 안되지 공원에서나 타게하던지"',
#    '"헬조선스럽네"',
#    '"없애라\\n무슨 젊은 놈들이 다리에 힘이 없냐?"',
#    '"아니 이런걸 기사라고..아 씨봉~ 순간 쑥 지나갈때마다 이말 나온다. 어디 겁나서 인도도 맘편히 걸어다니겠냐? 제발 없애줘라~"',
#    '"타지마"',
#    '"인도든 차도든 그냥 타지마라."',
#    '"없애라 ~ 돈 낭비 안전제로"',
#    '"물위로만 다녀줘~"',
#    '"세금내고 타  그럼  차도나  길을만들겠지  이나라  돌아가는거  당연한걸  따지네"',
#    '"레져용이지.. 이동수단은 아니지.."',
#    '"애초에 다닐수있는곳이 없는데도 불구 킥보드 들여왔쟈나 너네들이 허가해주고\\n. 어의가없음. 싹 치워버려라 킥보드"',
#    '"위험하다 생각 하면 타지마 쉐리들아 니몸땡인 중하고 보행자 남 몸땡이는 안중하냐"'],
#   ['"이륜차도 도로에서 푸대접 당하는 한국인데.. 자동차왕국인 이 나라는 도로행정재편을 하지 않는 한은 퀵보드는 정말 목숨걸고 타시길.."',
#    '"그냥 타지말아야됨"',
#    '"와~~~본인은 사고날까 무서워서 인도로가면 인도로 다니는 보행자들은 그럼 킥보드에 받힐까 무서워서 어디로 다녀야하나...."',
#    '"마음속으로만타"',
#    '"전동킥보드 자전거도로도 달리면 안되는 것으로 아는데 이상하네요"',
#    '"내근처에 안왔음좋겠다 혼자자빠져놓고 차때문이라고할까봐 겁난다"',
#    '"PM도 번호판달아야지"',
#    '"애초부터 도로 끝차선으로 다니는게 잘못된거지 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ전동퀵보드는 동네에서나 타라!! .제발 큰도로에 다니지마라 인도도 위험 도로도 위험 서로 다 안좋다."',
#    '"자꾸전과자 양성하지말고 없애라고 \\n애새끼들자꾸죽어나가는거볼래"',
#    '"골치 아프게 뭘 저런 걸로 고민을해~~~\\n어차피 골머리 아픈일도 많을텐데~~~그냥 없애버려,,, 자전거도 오토바이도 인도든 어디든 무법천지로 돌아 댕기는데 ㅠ 전동킥보드 까지 ㅠ 그냥 사고와 물의를 다분히 일으키는 이동수단 전동킥보드 인걸~~~그냥 없애 버렸으면 좋겠음"',
#    '"전동 킥보드 납품한곳 뒤좀 캐봐라 암만해도 불필요한걸 왜 만들어서 사고유발하고 사고나고 길에 막세워놓고 아휴~ 세금으로 별짓들 다한다"',
#    '"도대체 이걸 언넘이 승인해줘서 이 날리야~~~\\n그냥 없에주세요~~\\n타고다니는 사람도 위험하고 차량운전자도 위험합니다.\\n자전거 오토바이도 영 맘에 안드는데 이것까지~~~\\n까놓고 오토바이 단속 본적이 없는데 애들은 뭐 단속해~~~\\n첨 언론에서 떠들때 몇번 하고는 안하잔아~~~"',
#    '"킥보드도 나쁘도 오토바이도 나쁘다 ㅋㅋ 차 몰고 다니는 애들이 사실은 제일 인성 개빻은게 아닐까? ㅋㅋㅋㅋ"',
#    '"장애인이나 안전하게 제대로 다닐 수 았게부터 좀 해야죠. 킥보드가 문제임 지금 것도 안되는데?"',
#    '"차도로 가다가 한순간에 대가리 갈린다 조심하자 글고 저거 허가내준 놈들 싹다 태형으로 뒤질때까지 패라 말로하니까 되는게 없네"',
#    '"단속도 안되는 킥보드 자전거 오토바이 넘쳐나는데.. 만들긴 뭘 만들어?? 잘가는 차에 지네가 가서 박아 놓고는그래 차량운전자들한테 니네도 과실있다면서 대인접수 대물접수 해달라는 엿바꿔먹는 소리나 해대는데.. 그냥 다 없애라~"',
#    '"이런 기사는 빨리 삭제 조치해라"',
#    '"차도로 쌩쌩달리라"',
#    '"킥보드 없어지면 좋겠다\\n도로에서 너무 위험하다\\n차를 운전하고 다니다가 갑자기 튀어나와서  사고날뻔한 경험이 한두번이 아니다\\n그리고 아무곳에나 버리다시피 주차해놓아서 밟을뻔한것도 다반수다"',
#    '"어찌됐든 모든정책이 개판이야"'],
#   ['"진즉에 자전거길 확충했음 같이 다니게 혀도 될것을"',
#    '"무자비한 킥보드로 사고 위험이 많다"',
#    '"뭘 어째긴 어쨰. 걸어다녀 새퀴드라.... 안그래도 교통체증 최대인 한국에서 저속으로 저거 타고다니면 더 가중된다. 그리고 저거 없을땐 어떻게 살았냐? 기어다녔냐?"',
#    '"퀵보드 저건  인도  차도 관계없이  막다니더라 인도 코너  부위에서  튀어나오는 퀵보드 박을뻔 했다"',
#    '"그러니까 국민성이나 이용환경이 시기상조라고"',
#    '"ㅋ퀵보드업체한테 섭외당한건가"',
#    '"차도로 다니다 작은돌에만걸려도 넘어질위험이있다 도로에서 넘어지면 그땐너무 위험하다"',
#    '"탈 곳도 없고 야외 보관도 힘들어서 구매하려다가 포기"',
#    '"자전거 타고 다녀라 그냥"',
#    '"그니까 앞번호판 뒷번호판 의무화 하라고요  신고해도 못잡는다고 경찰이 그러더라 그리고 전동킥보드만 취재하지 말고  전기자전거도 좀 취재해 주세요 그것도 겁나 빠르게 인도 달리고 아무데나 세워 놓던데  내가 오늘도 초등학생이 공유킥보드에 걸려 넘어지는거 봤다  겁나 무겁던데 거기 애깔려봐라 끔찍하다"',
#    '"차와 충돌 안하고 킥라니 혼자 놀라 넘어져도 차에 과실 따지는 나라."',
#    '"제발 킥보드 사라지기ᆢ\\n2.3타는건 기본이고 아무데나두고가는 인성들ᆢ\\n번호판을만들어라 사진으로 신고할숭ㄱㅇ도로"',
#    '"그냥 없애라!"',
#    '"킥보드 없애라"',
#    '"여럿다치고 디지면 없어진다"',
#    '"타지를 말라"',
#    '"그냥없애자 왜자꾸사회적문제거리를만드는거야"',
#    '"그냥 타지마라"',
#    '"사륜차가시는길에 방해된단 말이닷! 엣헴!! 보행자 다니시는길에 방해된단 말이닷!!! 엣헴엣헴!!!!"',
#    '"땅바닦은 복잡하고 위험하고 하니까 금지 시켜야 할것이고 날개를 달아 놓고 날아 다녀야겠지"'],
#   ['"자전거 도로 공동사용 및  인도 차도 사용제한\\n범칙금 10마논"',
#    '"타지말란  말이다.  법으로  금지해!   차도는 차. 인도는 사람, 자전거도로는  자전거"',
#    '"다니지말란말이다"',
#    '"머리에 이고 뛰어라!!"',
#    '"차도로 달리는거지 어디로 달리기는"',
#    '"전동킥보드 회사에  깔아놓은 킥보드 갯수만큼 세금부과 해야 합니다"',
#    '"위험다니까 다니지말라고…자전거전용도로에서 같이 타던지"',
#    '"이륜차에 대한 법률도 후진국 수준인데 뭘 기대하냐?"',
#    '"OOO 나라에서 말타고  다니지  자동차가  뭔  필요있냐.  애새끼들  댓글들 보니  말이나  소타고  다닐 놈들이네."',
#    '"그냥 타지마라 대리기사같다 .. 킥보드,휠 다치면 중상이다"',
#    '"뒤에서 갑자기휘지나가면위험하다 길가는사람뒤치기당한다"',
#    '"없어도 잘다닌다"',
#    '"한국땅은 그 어느곳에서든 킥보드 때문에 킥보드 타는사람 보행자 차량 운전자 모두가 위험하다느걸 정치인들이 알리가 없지!"',
#    '"킥보드가 자전거도로로 다니는게 문제가 아니라 개념없이 다니는 킥보드들 때문에 문제인 겁니다. \\n기자가 자도에 1주일만 CCTV 설치해 놓아보면 사람들이 왜 전동킥보드를 싫어하는지 알게 될 겁니다. \\n헬맷 안 쓴 사람이 태반이고 역주행은 양반입니다. \\n기본적으로 도로규칙을 모르고 타는 사람들이 태반이다보니 움직이는 폭탄 같은게 전동킥보드입니다. \\n차도에서도 보는 사람이 간떨리게 타는 사람이 얼마나 많은지 기자는 조사해 보고 기사를 쓰기 바랍니다. \\n이런 한 쪽에 편향된 기사를 쓰지 말고 말이죠."',
#    '"전동킥보드 5차선에서 3차선 도로로 다님 그것도 밤에 기본수칙도 안지키는데 뭘 타고 다녀!!!"',
#    '"다니지 말란 말이다~~!"',
#    '"그리고 아무데나 방치된것들은 수거해서 한군대 모아놓고 주인이 찾으러가면 자동차처럼 견인비, 주차비 받아야함. 업체거면 업체가 내고....그게 싫으면 전용 주차공간 마련하던가. 왜 인도 곳곳에 방치해서 통행을 방해하나요?"',
#    '"전동 킥보드가 왜 필요한데?"',
#    '"인도에 타일 조금만 많이 튀어나와도 넘어져서 이빨나가는게 전동퀵보드.. 애초에 탈것으로서의 기본적인 안정성도 없는 물건임."',
#    '"사용하면 길에다 버리는 이유가 뭐냐"'],
#   ['"오세후니에게 물어보세요!"',
#    '"니들이 인도로 다니면 안위험하냐? 보행자들의 안전은 개똥이야?"',
#    '"그냥 아무데나 내팽겨놔서 저거 완전 없애야 됨"',
#    '"킥보드에 치이는 뺑소니 사고 당해 본 나로서는 어쨌건 반대. 신고도 불가능했음. 크게 안 다쳐서 다행이지만."',
#    '"고철폐기"',
#    '"전기 퀵보드는 나라에서 버린듯합니다. 뭐 이런 행정을 다하는지.."',
#    '"킥보드타라고 도로깔아줘야하나?말같지도않은 기사는 내리자"',
#    '"위험을 감수하고 타는거지 어디서 타긴  위험을 감수하기 싫으면 타지 말던가"',
#    '"바퀴 있는 장치들은 다 차도가 옳다\\n자전거도 차로 분류 되어 있어서 인도로 다님 안 되고\\n인도 오토바이 주행 당연 안 됨\\n인도 불법주차도 단속해야  한다\\n킥보드가 사람칠 수도 있는데 찻길로 보내야지"',
#    '"차도 끝으로 달리면 자신이 죽을것같고 인도로 다니면 남은 죽어도 자신은 안죽을것 같으니 인도로 다니겠지"',
#    '"이딴것 없이도 잘다녔다 보기싫다 길바닦에 널렸다 아무데나"',
#    '"업체 압수수색해서 면허증 없이 회원가입되어있는 것 부터 확인해라\\n도로교통법 모르는 사람들이 많다"',
#    '"차니까 당연히 찻길로 다녀야지 왜 인도로 다니면서 사람 치고 다니냐?ㅋㅋㅋ 그럴꺼면 트럭도 인도로 다니게 해주던가 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ"',
#    '"그냥 다 없애라\\n 기자 양반 대학교 앞에 가서 취재하고 이런 기사 쓰시오  두명은 기본에 헬멧도 없고 인도에 속도 엄청내고 사람이 킥보드를 피해서 비켜줘야되고 난장판도 아니고 골목 한가운데에 덩그러니 킥보드 두고 가버리고"',
#    '"타지말라구"',
#    '"하지마라.. 안그래도 위험한 도로에서 인도에서 술처먹고 헬멧없이 타는것들 그리고 아무데나 패데기 바람불어 쓰러지고 장점이 없다 장점이"',
#    '"없애라"',
#    '"타지마 씨발 퀵라니들아!\\n이게 지금 타고 다닐 인프라가 되는 나라냐고?!"',
#    '"돈 먹았냐"',
#    '"재활용처리장으로 가시면 됩니다."'],
#   ['"타지마라 백년 전에도 전동킥보드 있었다. 그때도 사고위험때문에 못탔었고"',
#    '"왠만한건 쫌 걸어다녀라"',
#    '"없애"',
#    '"나라를 더 후진국으로 만들어 가니~~"',
#    '"타지마 이 색이들아... 똑같이 교통법적용해서 벌금쳐내고 책임보험가입할꺼 아니믄"',
#    '"그냥 너네집 안방에서 타라는 뜻이다.....\\n밖으로 기나오지말고,,,"',
#    '"마당에서 이불 널을때 정말 편합니다. 런닝 머신하고도 호환이 잘 됩니다"',
#    '"다니지 마! 좀!"',
#    '"없애면되지뭘고민해ㅡㅡ"',
#    '"차선 하나 없애고 자전거, 킥보드, 장애인 스쿠터만 다니는 전용 도로 만들어라.. 기름 많이먹고 덩치만 큰 자가용만 도로를 차지하라는 법은 없다."',
#    '"전동 킥보드가 자동차도로로 달려야한다는 발상부터가 어이상실...  사고내 죽이던지 사고나 죽으라고 떠미는격이지.."',
#    '"이미 많아졌고, 공산국가가 아닌 한국이라서 강제할수는 없으므로 전동킥보드도 언젠가는 당당히 다닐수 있을겁니다 아직은 과도기고 전동제품시장에 돈도,인프라도 없어서 욕처먹는거지 사용자가 하나둘씩 늘어가는 흐름을 보면 언젠가는 도로도 새로 날거고 그에 맞는 교통체계도 구축이 될겁니다 전자제품인 만큼 AI를 기반해서 발전하겠죠"',
#    '"버스기사 쓰레기들 다 사고나서 인생 망해라!"',
#    '"대체 저걸 누가 만들고 상용했는지...\\n도로 교통법도 모르는 애들이 저걸타고 차도를 골목길을\\n질주한다. 아이 낳으라 홍보하지말고 있는 아이들이나 잘 키워야지 얘들 죽으라고 저런걸 도로에 돌아다니게 하냐...\\n무면허 운전보다 더 위험하다 ㅜㅡ"',
#    '"애초부터 만들지 말았어야함\\n\\n어디든 내 팽겨져있구 주행은 그지같이 하고"',
#    '"대안있지 법으로 정해서 이 사회에서 없애버리기"',
#    '"창고에 쳐박어. 도로에서 민폐끼치지 말고 . 킥보드충 타는 꼬라지만 봐도 트럭으로 갈아버리리고 싶으니까"',
#    '"속도 제한을 하든지 해서 더 보급해야한다. 사실 젊은 사람보다 나이든 분들이 활용하면 더 좋은게 전동 키보드다. 자동차를 대체할 좋은 이동수단이 될수 있다.."',
#    '"인도 차도로 자전거도로 킥보드도로?? \\n적당히 합시다."',
#    '"당신이 왜 사과해  조국이  사과해야지  표 얻을라고  당신네들 살자고 국민 이름 팔지  말자"'],
#   ['"좀만한나라에 좀만한도로"',
#    '"자기 편리함에 안전하게 탈려고 자전거도로에 들어오는것은 괜찮나?"',
#    '"이거 왜 타고 다닐까요?그렇게 위험함 교동수단인네  이해가 안가요"',
#    '"아니 씨이일발 타지 말라고!!!"',
#    '"없애라고..."',
#    '"앞에서 알짱대지말고 인도로 꺼지던가 걸어다니던가 뭔 좁은도로에서 킥보드야"',
#    '"타지말라는 얘기다! 제발 타지 좀 마라!"',
#    '"오토바이 자전거 다 없애! 사고로 치면 오토바이나 차사고로 사망사고가 더 많아!"',
#    '"나 후진할 때  뒤도 안보고 그냥  막뺀다,  받혀 뒤저도 난 몰라~"',
#    '"도로건 인도건  가운데 내팽가치고  가버림.  다닐곳은  공중에 날아다녀야."',
#    '"킥라니들 존나 찐따같음.\\n 제일찐따는 양복차림에 가방메고선 타고다니는 킥라니."']],
#  [['"보행자와 운전자 모두에게 민폐끼치는 존재..."',
#    '"솔직히 사고나면 차대 차로 인정해줘라. 이건 뭐 무법자여 다치면 차 잘못이공"',
#    '"오죽하면 킥라니라고  하지  않겠나  안전장치  미착용은  물론  여기저기서 툭  튀어나오고  아무렇게나  방치하고  너무  위험하다 법을  강화하든지  없어졌으면한다"',
#    '"외국처럼 번호표지판 의무화하고 자격증따게해라. 헬멋은 당근이고"',
#    '"저러다 다치거나 골로 가면 나라는 뭐했냐며 이상한 소리나 하고"',
#    '"저거 길바닥에 널부러지게해서 아무나 막 탈수있도록 허가해준 넘 찾아 철저하게 조사할필요가 있어보인다.\\n얼마나 또 쳐드셨는지...  가뜩이나 어지러운 세상.. 저것때문에 출퇴근길 완전 더 어지러움.. 누구 대가리에서 나온건지 진짜.. 운전하기 진짜 개짜증남.."',
#    '"이정부들어 헛짓거리 1호다. 킥보드를 왜 허가해서 이사단을 만드는지.. 답답한정부 어후~~"',
#    '"사고나면 당연히 최소 자동차 수리비,감가비, 사건수습동안 렌트비, 운전자 시간에 대한 보상비, 운전자 정신적 피해비, 합의금 다 물어 내게 해야 된다"',
#    '"이거 파보면 이번 정권에서 분명 해먹은 놈 있다. 킥라니는 재앙이다. 재앙~"',
#    '"안그래도 운전할때  ..인도걸어갈때 엄청 짜증남!!  이거 누가 승인한거야?! 미국처럼 차없음 안되는 나라면 몰라도 울나라처럼 대중교통 잘되어있는 나라에서 이게 왜필요하지??!!\\n아무데나 세워놓구 !!  킥보드 타지말고 운동되게 걸어라!!"',
#    '"킥보드 없애라. 저거 삐리나 양아치 아니면 타는 사람 없다. 사람 치고 그냥 도망가는 건 기본이고 아무 데나 던져 놓고 사라지고 특히 어린 번죄자 후보들 두셋 타는 것도 흔하다. 괜히 정상인들 뼛골 뽑으려고 만든 것들 좀 버리자. 범죄자를 보호하는 법 논리로는 어려운가?"',
#    '"킥보드 타는걸 법으로 금지 시켜주세요. 이건 자리니 보다 더위험하다."',
#    '"이게 웃긴게 오토바이처럼 속력나오는데 헬멧단속없고 . 미친듯이 가로지르는 애들때문에 하루에 몇번이고 눈살찌푸림."',
#    '"저런것들은 차로 치어 죽어도 무죄 받아야 맞아."',
#    '"회사들 완전 퇴출시켜라 오늘 길가에 주차하는데 내려서 3대 치우고 탔다. 왜 지들돈벌고 우리가 고통받아야되는데?"',
#    '"타는것도 불안불안하게 타는데 왜 남의 집 주차장입구에 방치를 시키냐고"',
#    '"2명, 심지어는 3명씩도 타니  법으로 규제해서 공유 킥보드는 없애야 한다"',
#    '"킥보드업체 퇴출시켜라"',
#    '"이거 언제 금지화할 거야? 아무 대책 없이 허용해준 것 자체가 이해가 안 되고, 이 정권은 무법천지에 공중도덕이라고는 찾기 힘든, 무질서한 중국의 모습이 워너비인가???"',
#    '"헬멧 없으면 대가리 깨져도 죄를 묻지 마라.."'],
#   ['"킥라니랑 사고나면 킥라니 과실100 하자"',
#    '"이거 통과시킨 shake it 누구냐"',
#    '"킥보드 없애주세요..엄청 위험합니다.."',
#    '"역주행하는 킥보드랑 차랑 부딪히면 누구책임인거죠?  역주행 너무 많이하고 곳곳에서 하도 튀어나와서 차대차면 그냥 나도 안비키려구요."',
#    '"1인승 킥보드에 커플이 타는 거 많이 보이는데 같이타자는 남자 믿고걸러라 니 목숨 500원짜리 동전으로 보는 놈이고 같이 타자 조르는 여자는 머리가 빈 걸래니 그냥 버려라."',
#    '"전동킥보드 퇴출시켜라"',
#    '"이런 업체들 없애버려라. 소수때문에 많은사람들이 불편한데 답나온거 아니야."',
#    '"법이 잘못되서 그런거 같아요.\\n오토바이나 킥보드등 이동수단과 자동차와 사고가 나면 자동차 잘못도 아닌데 자동차 한테 과실이 크게 적용되니 더 무법으로 타고 다니는듯 사고나면 보험금 받으면 된다는듯..\\n교통법규도 지키지 않고.."',
#    '"공유퀵보드들 부터 없애라 진짜ㅡㅡ"',
#    '"퀵보드 때문에 무고한 운전자 전과자 되는건 재수가 있고 없고의 문제가 되었다 누가 이런걸 계획하고 실행했는지 정말 미친짓이다~~!!"',
#    '"넘 위험해.   차도 사람도 못지나가게 아무데나 세워놓고\\n   갑자기 휙휙 옆으로 지나다니고.  에휴... \\n   인도가 더이상 안전한 인도가아니야. \\n         차.오토바이에 킥보드까지~"',
#    '"그냥 사고나 다 죽어라"',
#    '"킥라니는 암적인 존재임.도로의 무업자로 교통신호 무시하고 막 뛰어 나오는데 사고나면죄다 자기가 피해자래.\\n법도 개같고 킥라니들은 인성도 개같음.\\n운전자들 킥라니는 더러워서 피하는 겁니다.\\n막장 음주운전자들은 눈에 뵈는게 없어서 그냥 차로 밀어 버리겠지만..."',
#    '"견찰분들 단속한다면서 영상에 나오는 태반이 하이바를 안씀 ㅋㅋ 세금 뜯어야져~~~ 뭐하세요~~~ 2명이 타는건 기본이고 3명 타는것도 있더만 단속안하세요??? 아!! 그거까지 하려면 인원이 부족하다고 할텐데 여경을 뭐해요~~~~~ 여경은 뽑아놓고 춤이라도 추라고 있는거 아니자나요?"',
#    '"타는건좋은데\\n조심히타고\\n타고나서 제발\\n좀 여기저기 아무\\n대나 세우고 눕혀놓\\n지말고 잘세워서 \\n두세요ㅡ ㅡ아님 다\\n싸그리 치워버리\\n던지해주세요"',
#    '"문재인이 타라 ᆢ사고나뒤지게"',
#    '"진짜 몇년 사이에 완전 개판 만들어놨다!!!"',
#    '"알면 대대적인 단속좀 벌여라 불법주차한 킥보드는 다 견인좀하고"',
#    '"킥보드없애라운전할때마다가슴졸인다  걸어다녀라 건강에도좋다"',
#    '"저런 전동 킥보드 법적 보호해 주지 않아야. 법을 지킨다."'],
#   ['"아무리 편리하고 좋은 것이라고 쓰는 사람들의 시민 수준이 낮아 다수애게 피해가 온다면 없애는 것이 옳다"',
#    '"그냥  밀어버려라.\\n그래야 킥라니들 정신들 차리지"',
#    '"없어졌으면 좋겠다 미친다 부모뒤에 숨어 보험금만 노리는 자식들 자동차운전자가  무슨 봉인줄아나  완전 똥값물어준다"',
#    '"그냥 다 주거랏"',
#    '"식물인간되면 정신차리니 걱정 안해도 된다."',
#    '"단속해서 세금 걷어."',
#    '"그냥 없애라 문제 더커지기전에"',
#    '"킥보드는 없어져야 할 1순위. 오토바이만큼 위험함. 정부와 지자체에서 왜 허용해 준거? 돈을 받았나봄?"',
#    '"두 다리 멀쩡한데. 저런거 타고 다니면 안쪽팔림?.. 남한테 피해주고 남 시선 따윈 신경 안쓰는 사람들인가? 도덕 교육 안받았나"',
#    '"자동차/오토바이/전동퀵보드/자전거 다 똑같다. 본인이 잘 못 해서 사고나면 스스로 다 책임져야지. 약자니 그런거 따질게 아니라 정확하게 과실로 비교해야 한다."',
#    '"도로법, 도로교통법은 크게 “차도”와 “보도”를 구별하면서 “차”는 차도로 사람은 보도로 가게끔 규정하고 있는데ㅡ우리나라 사람들 대부분은 “차”가 뭔지 모름. 쉽게 말해 바퀴 달린 건 (유모차 정도 빼면) 다 “차”라고 보면 되는데ㅡ자전거고, 킥보드고, 심지어 오토바이고 전부 다 지가 “차”가 아니라 사람인 줄 알고 보도로 막 달림. “차도”에 있는 신호등은 분명히 빨간불인데도 무시하고 막 다니거나, 사람들하고 같이 횡단보도를 건넘. 너무 무식한 인간들이 많음. 경찰청에서 좀 계도해야 함."',
#    '"킥보드 다 없애자\\n제발"',
#    '"도데체 전동킥보드는 왜 사용하게 해놔가지고 이래저래 민폐를 만드냐 세금아니냐 이것도?"',
#    '"민도가 아직 일본의 1/4 수준도 못따라 간 듯. 어린 애들도 저러니 30년 후가 돼도 별로 달라지지 않을 지도."',
#    '"저런거 단속 안하고 머하냐? 대체"',
#    '"오토바이 킥보드 진짜 너무 위험해요 특히 킥보드 헬멧도 안쓰고 2명타고 지하차도 막 달리고 신호위반 하는거 자주 보니... 진짜 걱정되고 또 인도주행 하는 사람이 경적도 없이  걸어가는사람 바로옆에 쌩 가는건 진짜 극혐... 킥보드 강력규제나 위반처벌 심각하게 해야될껏같아요"',
#    '"우리아파트 출입구 앞에 꼭 주차하는 사람 정말 민폐다! 그 출입구로 짐 가지고 들어가는 사람들, 유모차 끌고 들어가는 아이 엄마들, 어르신들, 장애있는 분들 출입의 불편을 주며 그 앞에 주차하는 건 대체 무슨 생각인건지..!ㅠ 좁은 인도 가운데에 세워놓고,,심지어 때론 가로로 가로막아 세워놓은 것도 봤음! 또 어두운 밤에 아파트 단지내에서 2명이 매달려 꺅~꺅 소리지르며 내 옆을 미친속도로 스쳐지나가는데 진짜 깜놀함!ㅠ 안전 교육 강화 및 불편 신고 3회이상 쓰리아웃처럼 잦은 신고받는 경우 이용못하게 하는 제도가 있으면 좋겠습니다!"',
#    '"그냥 법 없애고 맘편히 타게 하자 그리고 맘편히 보내드려 하늘나라로... 지들 안전 생각해서 타라고 백날 말해도 안 들어쳐먹는데"',
#    '"저런 인간들 살리자고 시행한게 5030"',
#    '"아무데나 놓고 다니는것도 진짜 극혐임"'],
#   ['"저런것들은  덤프트럭으로 갈아버려라"',
#    '"좀 없애자."',
#    '"킥보드업체 정리하고 규제하는 수밖에..."',
#    '"어떤세기가 킥보드 온데 뿌려서 엉망이다 엉망."',
#    '"많이 다치고 죽기를~도로에 암적인 존재"',
#    '"저딴식이면 못타도록 없애는 게 맞다"',
#    '"무분별한 킥보드 도입은 처음부터 잘못된것 더 많은 사람에게 불편을 초래한다"',
#    '"시행했으면 강력하게 단속.. 처벌하라!!"',
#    '"사고나서  다 디져뿌러라"',
#    '"다없애라! 민폐덩어리"',
#    '"그리 따지면 자동차.오토바이. 자전거. 다 위험! 그냥 다 조심해서 운전 하는거지! 뭐 있냐? 삶 자체가 다 위험인데.뭐"',
#    '"얼마전에 사람많은 인도로 전동킥보드 탄 인간이 슉슉 지나가서 사고날뻔했다. 그런인간들 빡세게 잡아서 벌금 물도록 해야한다. 헬맷도 없이 타더만"',
#    '"없애라...누구 좋으라고 이 위험을 유지하고 있는 이해가 안된다"',
#    '"이렀게 다니는 킥보드를 어떻게 피하나? 정치하는자들 네들은 피할 수 있나? 공원에서 놀이기구로만 타게 하던가? 사고가 안날수가 없는걸 길에서 타게 한놈들이 문제다.!"',
#    '"자전거 말고 다 치워버려"',
#    '"그냥 받아버려라, 다쳐야 정신차림"',
#    '"킥보드 이용자는 법규등 지키는사람 못봤다"',
#    '"휴대용 전동기구들 원천적으로 사용금지 법안을 만들어라"',
#    '"저렇게 다니다가 차에 처죽으면 차 수리를 보상해주는법 발의해라. 차주는 먼 죄냐"',
#    '"여기저기  뒤죽박죽  아무대나  세워져있어   위험 하다.  \\n없어졌음  ."'],
#   ['"정말 아무데서나 튀어 나오는거 보면 목숨내놓고 타는듯"',
#    '"대중교통 잘된 나라에 킥보드 왜 필요한지?   도심  혼잡한데다가 골목 여기저기 방치되어 위험천만함.."',
#    '"공유킥보드는 없애라 그냥"',
#    '"그냥좀 없애라 암덩어리다"',
#    '"헬멧 안쓰거나 인도로 다니는 것들은 사고 좀 나야 함. 물론 지들끼리"',
#    '"박원숭. 민주당 작품"',
#    '"운전도 뭣같이 하는 나라에서 킥라니는 더하면 더했지"',
#    '"서울에서 어디선 안전하고 어디선 위험하다는게 어딨어? ㅋㅋ"',
#    '"공유킥보드 좀 없애라.."',
#    '"도로위의 날파리."',
#    '"자전거랑 저거 차도에서 타지 않으려면 다 폐지해라"',
#    '"이동의 편리성을 위해 만들었던 건데\\n지금은 주로 놀이용으로 사용되어지고 있는 듯 합니다.\\n보행자는 걷다가 피해야 할 정도로 킥보드 운행은 위험해 보입니다.\\n게다가 아무곳에나 널브러져 있는 것도 사고위험이 있습니다."',
#    '"걍 냅둬라 돈 많은가 본데 치면 드러눕게... 3개월만 푹 쉬고싶다."',
#    '"타는거 봄 열통터진다 아주그냥 곡예사여"',
#    '"도로교통법을 바꿔주세요.\\n약자를 보호하는게 아니라, 법대로 하자고요.\\n자전거, 키보드, 오토바이등 불법적인 운행시 사고나면\\n그 책임을 모두물게하자고요.\\n자동차 전용도로타는 오토바이... 이런건 사고시 차량운전자에게 보상을하게하고 불법저지른 오토바이는 죽든 OOO이되든\\n벌금내게하고요.\\n불법저지르면 고의로 쳐박고 갈아버리고 보상받게해주세요.\\n불법을저지르는 것들에게 박히고 보상해주는 이런법은\\n도대체 뭔가요?"',
#    '"저거 없애면 안되나??"',
#    '"킥라니 = 딸배"',
#    '"병원에서 뇌사자 기다리는 분들께 희망을 주는 킥보드... 열심히 헬멧 벗어서 타시고 장기기증 하신 후 떠나세요."',
#    '"킥보드 지나다닐 때마다 아킬레스건이 찌릿찌릿해..무슨 공유킥보드 진짜..."',
#    '"저런 것들은 진짜.. 뭐랄까.. 뇌가 없나 봄..."'],
#   ['"하여간 서울것들이 문제다  서울것들이 나라를 망친다"',
#    '"언제부터 퀵보드를 탔다고 사업전부 폐업시켜라.... 안그러면 계속 죽는다...어린넘. 젊음넘....... 군대 가기전 OOO이나 하늘나라로 간다...."',
#    '"오징어게임 옷이라도 입고 타라그래 불법주행 신고라도하게"',
#    '"견찰들 나와서 단속 좀 해라.어디 찌그러져서 자빠져 OOO 말고.@.."',
#    '"킥보드 아주 미친 거 같다. 사람들 사이 차량들 사이들 즐겁게 지나간다. 그러다 한 대 맞는다."',
#    '"역겨운 킥라니새기들 ㅋㅋㅋ 안전장비나 착용하면 양반이지 다 쳐뒤졌으면"',
#    '"어설프게 치면 평생책임진다~밀고들어가라~ 덤프트럭 마인드였죠~ 요센 일반자동차도 마찬가집니다~각자도생"',
#    '"무면허 애들이 타고있다. 무면허로도 탈수있고 안전장비없이도 탈수있다고 안다."',
#    '"숨이 끊기면 장기를 꺼내어 필요한 곳에 ….."',
#    '"일단 프랑스 파리나 런던 같은 도시들은 다 허가제(permit)라는 제도를 통해서 딱 제한된 대수만 운영되도록 하고 있다고 하는데요. 우리나라는 안타깝세 허가제가 도입이 안되고 있는데 근본적인 이유는 시민들의 무관심 때문에 그렇습니다. 그냥 킥라니가 싫다거나 혐오발언을 하기 보다는 해외처럼 딱 제한된 업체에게 제한된 대수로 운영하도록 시민의 권리를 주장할 필요가 있어 보여요. \\n\\n뉴스 콘텐츠 면에서 작년과 올해에도 방영됐던 내용을 그냥 데스크에서 시켜서 시즌 기획으로 푼 것 밖에는 안보입니다. 깊숙히 진짜 원인과 흐름을 취재해 주세"',
#    '"전동킥보드~~자라니보다 더한 존재~~~\\n솔직히 말해서 스쿨존 불법주차사이로 튀어나오는 애새끼들보다 더 위험한게 킥라니다....쫌 없애라...."',
#    '"강남대로 인도에서 옆으러 쌩 못 지나가게 해라. 정장입고 철 없어 보이더라"',
#    '"타는사람도 위험하고 운전자도 소리없이 갑자기 달려드는 킥보드때문에 너무  위험하다.\\n없애야한다. 자전거를 타던지 걸어다니든지 해야."',
#    '"저것도 파헤쳐 봄 비리가 있것지"',
#    '"그렇게 걷는게 싫으면 그냥 다리 자르고 전동휠체어 타라"',
#    '"저번에 별로없을 밤시간에 고딩들이 오토바이안타고 저거타더라;; 차도에서 타고다니던데 하이바도안쓰고 2명이서 폭주족마냥 중앙선넘어서 지그재그로"',
#    '"아무데나 옆으로 슝슝 다니고 앞에서 돌진 해 오고 놀래고 불안하다... 당장 없애버려라."',
#    '"공유킥보드는 뭔 공유킥보드여 걍 없애버려 저런게 왜 필요함? 자동차도 아닌것이 보행자도 아닌것이 그렇다고 보호구 착용하고 제대로 타고다니는 것도 아니고"',
#    '"킥보드 찐따들이 타고 다니는거 아니냐?"',
#    '"로드킬이 고양이가 아니고 사람이 될줄이야~"'],
#   ['"왜  법을 OOO이 만들어서 운전자만 개값물게 만드냐?"',
#    '"킥보드 없애라 !!!"',
#    '"죽을려고 작정한 사람들까지 법으로 보호하지 마라."',
#    '"없어졌으면좋겠다..인도가 완전 지저분"',
#    '"정부차원 대대적 구매및 지원정책.. 중국자본하고 유착의심이 매우 강하게드는.....  진실을 밝혀주겠지? 누군가는?....."',
#    '"킥보드 우리나라에서 퇴출해야해요!!! 주차두 아무데나하구 \\n길가에 버리고 가는 사람도 잇고 질서가 안되잇음"',
#    '"탈거면 공원안에서만 허용해라!!\\n돈주고 빌려타는 자전거처럼!\\n타구나서 아무대나 주차하니 차가 피해서 가다 사고 날뻔한적이 한두번도 아닌데다가 골목이나 길가 아무대서나 툭툭 튀어나오니 놀란가슴 쓸어내린적이 백번도넘고...대체 무슨생각으로 길거리운행을 허용한지는 모르겠지만 이건 진짜 아닌것 \\n같습니다. 사고나면 차량주가 독박이니 지금 당장 거리운행을 중단하고 모두 공원에 넣고 일반으로 갖고 있는 사람들도 공윈에서만 탔으면 합니다 아님 법을 동등하게 강화시켜주세요"',
#    '"자전거나 킥보드는 인도에서도 통행가능하게해라 인도에선 뒤질일없지만 차도에서몰면 운전자도 빡치고 뒤질가능성도 엄청나게 올라가지"',
#    '"킥라니"',
#    '"저거 어떤국OOO이 허가해준거냐"',
#    '"퀵보드 없어도 공유경제 돌아간다"',
#    '"유튜버 화살촉들이 나서서 처단 하자~!"',
#    '"킥라니들 사형시켜야합니다"',
#    '"저걸 왜 허가해준건지 진짜 신경질난다"',
#    '"같이타는커플들 진심으로 대가리 깨지기를 빈다"',
#    '"하루에 서너번씩은 보지 킥라니들"',
#    '"ㅋㅋㅋ 대통령도 민주당 국회도 민주당  권력은 지들이가져놓고  법안만든다고 국힘 욕하는건  정신병자냐 뭐냐대체 ㅋㅋㅋ 민식이때처럼 잘해보지 그래"',
#    '"걍 빨리 뒤지라해 뭐하려 법을 어기면서 살라하냐 저거는…"',
#    '"차로 머리 한번 넘어가서 죽는 사고 나면 구경가야지..머리 터질라나....궁금하내..안터지나..터지나..애들 머리는 터질라나.."',
#    '"저런건 비퀴로 밟아서 머리를 터트려야하는디"'],
#   ['"치료해주니까 저러지.. 지몸 지돈으로 치료한다고해도 저럴까? 법좀 바꿔라...제발"',
#    '"없애길...개인이 사고시 모든책임과 보상을 책임지는 법이 생기는게 아닌이상!!보행자에게도 운전자에게도 피해만 입히는 애물단지임!!책임은 없고 나혼자 편안함있는..단속도 이렇다할 처벌법도 없이 위협만되는걸 왜 풀어둡니까?이따위로 허가할거면 모든피해는 나라에서 책임 지시던지..억울한 피해국민 그만 만드시고!!"',
#    '"전동퀵보드 오토바이등 모두 자동차와같이 차선지키며 가게 법계정하고 번호판 달아라 전동퀵보드는 퀵보드 핸들기둥에 헬멧함 구비 의무화시키고"',
#    '"킥보드 다 없애자 오토바이도 지랄인데 킥보드까지 보태는구나"',
#    '"다 견인해가라 제발~~"',
#    '"제발 보도에는 올라오지 말아주세요"',
#    '"하,,, 진짜 짜증나 저런사람들"',
#    '"예전엔 오토바이 욕했는데 킥보드에 비하면 양반이였다. 킥보드로 배달하는 애새끼들 진짜 잡히면 죽이고 싶음"',
#    '"타기 전에 타다 죽어도 법적 책임은 본인에게 있다는 각서 쓰고 타게 해라"',
#    '"첫 대여부터 1만원 추가로 받고 지정 반납장소에 가져다두면 돌려주게 해야한다."',
#    '"없애라 쫌"',
#    '"킥라니 OOO"',
#    '"다들 목숨이 몇개쯤 되나봐"',
#    '"킥라니족 ㅋㅋ"',
#    '"불법 주차된 퀵보드나 좀 쓸어 갔으면 좋겠다.. 어차피 소유 회사에서 다 내야하니 세금도 받고 좋네.. 구청은 지하철 입구 앞의 퀵보드에 주차위반 스티커 팍팍 좀 붙여라.."',
#    '"길거리에 퀵보드를 많이   배치 해 놓은 저의가 뭐냐?\\n싹다 없애라"',
#    '"면허 있는 사람만 타야 하는데 중고딩들 도로를 그냥 안방처럼 가로질러 ㅠㅠ 그때마다 걔 부모님 심정이 되어 소름 소름"',
#    '"누가 허가내준거냐구"',
#    '"얌전히 탔을때 사람취급이지 뭣같이 타면 그냥 고라니다"',
#    '"조만간 국회의원 차 제대로 들이 받을듯. 쓸데없는데 인생걸지마라."'],
#   ['"아예  철수시키고  사용못하는 킥보드  버릴순 없으니\\n한강공원에서나 기간정해 영업토록 해라."',
#    '"안전규정 미준수시 범칙금 및 과태료 강력하게 부과하고 계속 사고 발생시 킥보드 운영 전면 중단해야합니다  안전을 위해 강력한 규제가 필요합니다"',
#    '"정부잘못. 당장 금지하라."',
#    '"킨라니들우 다 OOO지."',
#    '"저런거 차로치면 상줘라~그래야 한방에 근절된다~~ 백날 언플해봐야 할놈들 다 하자나~ 차로 쳐서 죽이면 상주면 하는사람 아무도없음ㅋ"',
#    '"누군가 크게 다쳐서 이슈가 되어야 경각심이 생길듯 하다가도 시간이 지나면 똑같겠짘ㅋㅋㅋㅋ"',
#    '"보도운행 하는 킥보드 자전거 고위로 부딪쳐서 합의보세요"',
#    '"킥보드가 죄다 중국산이자나요 헤헤"',
#    '"킥보드회사에 로비쳐받고 입법한 국개 사퇴바람"',
#    '"킥라니"',
#    '"전동 킥보드 처음에 입법에 관여한 국회의원 다 옷 벗어라. 이렇게 인도 차도 다 좁은 나라에서 전동 킥보드가 맞기나 하니???"',
#    '"전동 킥보드 이용자는 법을 지키고 국가 역시 시대가 변화한 만큼 이용자에게 모든 책임을 넘기지 말고 대책을 마련해야 합니다"',
#    '"뒤질려고 환장한 놈년들이니 소원대로 뒤지게 해줘라 컄ㅌㅌ"',
#    '"킥라니들  차로치면  난 보험접수무조건 안해준다"',
#    '"요런 것들은 깔아 죽여도 되지 않나?"',
#    '"대가리안쓰고 다니는 애들 진짜 개꼴뵈기시름.."',
#    '"킥라니들은 차로 밟아도 무죄"',
#    '"저것들이 인도를 얼마나 생생달리는데"',
#    '"그냥 킥보드는 법으로 꽁꽁묶어놔야함"',
#    '"킥라니들은 차로 치어죽여도 무죄로 만들어줘야댐"'],
#   ['"보험이나 과실부분이라도 명확하게 해라 가해자인데 피해자에게 보상도 제대로 안이루어지고 과실은 두루뭉실 피해자 두번죽이는 하놔"',
#    '"킥보드도 교통규범 어기면 처벌할수있게 번호판 달아주세요"',
#    '"말않듣는 애들 걍넵둬라\\nXX버리게\\n백날얘기해도 말않듣는다"',
#    '"킥보드법 안만드냐! 무슨법ㆍ무슨법 잘도 만들더만 킥보드법도 만들자"',
#    '"제대로 된 규제가 반드시 필요한 시점"',
#    '"그저 유럽 몇몇 나라에서 한다니까 따라하느라 따릉이로 헛돈 쓰고 킥보드로 헛돈 쓰고"',
#    '"강남은 저게 최고네 ㅋㅋㅋㅋㅋ"',
#    '"저렇게 타는  인식이  거의 병진에  가까움   받히면 지만죽는데 차가  서줄거란  막연한  기대감으로   저짓거릴 하고있으니....   뭔 병진 짓거리인지....  탈때  목숨걸고 탄다는 생각좀하길....   차는  스쳤지만  너는  골로간다..."',
#    '"죽지말고 장애자 된서 평생 휠체어 타고 다녀라"',
#    '"저것들 다 그냥 혼자서 죽었으면..."',
#    '"타는사람이 뭔잘못이냐 애초에 저럴걸알면서 길바닥에 깔아논 어떤 멍청한놈 대가리가 문제가있는거지"',
#    '"맨날 일본이 더 잘한다고 빨아제끼더만 킥보드 번호판은 안따라하나?"',
#    '"시커먼게 훅하고 지나가면 전동킬보드다 진짜 킥이아닌 킬보드~ 차보다 더 빨리가려고하고 횡단보도 훅지냐가고 둘이 타고 헬앳안쓰고 개판이다"',
#    '"인도에서 위험한킥보드 ᆢ\\n기본2인이상 타는겨우도잇는데 법이 강하해야하고 벌금형도만들어야함 번호판을만들자"',
#    '"전부 없애라   저거 전부 중국산인거 알지 국내 돌아댕기는 저거 90퍼가 중국산이고 저것조차도 친중문패거리들이 도입해서 정부보조금받고 국내에 전국적으로 깔아논거다"',
#    '"인도로 다니는 놈들 바로 차고 싶어짐"',
#    '"딸배랑 동급"']],
#  [['"제도고 나발이고 공유 킥보드 다 폐업시켜라. 개인용을 타야 아무 곳이나 버려놓고 안가지"',
#    '"공유 킥보드 문제 많죠.. 헬맷까지 렌탈되는 경우는 거의 없고, 그렇다고 일부러 헬맷만 들고 다니면서 공유 킥보드 이용하는 사람은 더 없으니 타는 사람도 안전 문제가 있고, 도로로 주행하면 차량 운전자 입장에서 불편하고, 인도로 가면 행인들이 위험하고.. 암튼 킥보드 극혐"',
#    '"없애라. 박원순이 싸지른 똥 중 하나."',
#    '"폐업하기 바란다 자본주의 사회에서 공유는 100% 망하느니라"',
#    '"킥보드 아예 폐기처분하면 안되나? 걸리적 거리고 아무 곳에 두고 가고 관리도 안되고.. 참 답없다."',
#    '"홍의원님 공유 킥보드 어느 한 업체 지분 보유하고 있는지 의심됨. 서울시에서 무허가 신고제 사업이라고 못을 박음. 절대로 허가 받고 하는것 아님."',
#    '"세금으로 뭔 짓이냐? 이것도 시민단체라는 사회주의세력들 먹여살리는 거냐? 공유라 쓰고 세금낭비라 읽는다"',
#    '"견인차가 킥보드견인하는것이 더웃긴일이다 ㅋㅋ 역시 뇌는 국영수위주로만 세금은 필수적으로 쫙쫙 빨아먹지"',
#    '"근데 저거 기본은 세금으로 구매된게 아닌가요?..정말 몰라서 궁금해서 질문한거구요...그리고 폐기시 밧데리는 따로 분리해서 해야 되는걸로 아는데...제데로 되고 있는지 궁금하네요"',
#    '"공용킥보드는  왜 만들어가지고  인력 낭비하고 걸어다닐때도 위험하고  운전할때도 차도반 인도반에  걸쳐진 킥보드 피하느냐구 \\n짜증난다.  도로에  나뒹굴때도  있고 ㅡㅡ\\n제대로  못할거면    시작를 말지  ~~  선진국 따라할꺼면  제대로  알고  따라하던지  뭐하는건지..진쫘~~  두명이타는건 쉽게 볼수있고  여기저기서 슉슉  뛰어나오는데  진짜 사고날까  무섭따."',
#    '"킥라니 다때려부셔라 저런것들 얼마나 운동도하기시르면 저런것까지 타고다닐까"',
#    '"문재앙 보고있냐?ㅋ 4차산업 교통수단이라면서 죄다 중국에서 들여와서는 주민들 민원 귓등으로도 안듣고 시진핑에 돈 바쳐\\n 차이나타운 수십개 만든 저우위보 그 여편네랑 강원도지사 최문순 그 난리하게 만들어. 아오 C 북괴간첩도 모자라 중국공산당 개돼지. 공공기관 공공연구소는 무슨 보고서 올릴때마다 되도 않는 &lt;4차산업 시대&gt; 이 문구 전부 다 집어넣으라고. 4차 산업이 니 마누라 이름이냐. 허구헌날 외쳐대래 아우 주사파문주건달노무그지야"',
#    '"이거 주차하는 개념없는 것들이 더큰문제이지 렌트카빌려도 암무대나 주차하냐 과태료도 4만원이면 차랑같아야지 마지막이용자가 내야 마땅하다"',
#    '"잘한다견인해라  \\n\\n업자들 돈벌지못하게  처벌해라"',
#    '"신성장산업? 헛소리 지껄이질 말길 무책임한 돈벌이일 뿐"',
#    '"없애주세요.아파트도로에눕혀놓고간애들.SUV는보이지도않는데...범퍼교체값만나가고.누구한테보상을받아야하는지.\\n개념있는애들이라면거기에다세워놓고갔겠냐고...신호무시하고가로질러가는무서운애들.제발없애주세요.차를모는운전자는무슨죄란말이냐"',
#    '"우리나라 시민의식은 후진국 수준인데 그걸 너무 간과했다고 봄. 업체자체에서 메뉴얼을 정해놓고 관리를 탄탄하게 했어야 했다. 걍 원숭이들한테 킥보드 던져준거임"',
#    '"아예 지 개인전용으로 쓴다고 아파트에 박아두고 계속 쓰는놈들도 있던데 볼때마다 회수요청 전화함.."',
#    '"다 사서쓰게해라 본인 것이면 저렇게 못쓸텐데~ 정말 양심없는 인간들이 너무 많다"',
#    '"애초에  승인해준 사람들이 문제지\\n저럴줄 몰랐을까?"'],
#   ['"공무원들이 문제지... 개 새... 대체 아무랗게나 두고 가도된다에 하가를 내준것둘이 문제다... 주차장을 두고 거기에 정렬하더럭 하고 아니면 벌금이든 뭐든 제제를 줘야지... 어디 개팽게쳐 두듯이 던져놓고 가면 다른 사람은  왜 보행에 불편을 격어야하나? 이런 불편 만들려고 허가했나? .. 공무원들 대가리가 그정도 밖에 안되든지... 돈을 쳐 먹었든지..."',
#    '"신산업은 개뿔.. 보조금 개인정보 중공간첩산업이지..."',
#    '"킥보드에 CCTV 설치 및 노헬멧과 무면허 탑승시 징역 1년때려라 그게 유일한 답임."',
#    '"킥보드때문에  주차할때  꼭한번씩 내려서  킥보드 이동시켜야한다   킥보드문콕도 엄청많아졌고."',
#    '"공유킥보드만 저렇지 개인킥보드는 저렇게 아무데나 주차하거나 내팽겨치지 않는다."']],
#  [[]],
#  [['"지지합니다^^"']],
#  [[]],
#  [['"킥보드 주차 구역 만들어서 업체에 비용청구 하던가. 불법주차 해놓으면 벌금 부과 하던가."',
#    '"처음부터 앞뒤 안 가리고 만든게 잘못이지"',
#    '"서비스하고 있는 업체들이 법규를 무시. 방조하며 서비스를 하고 있는데, 강한 처벌을 해야합니다. 진짜 인도에 걷가다 뒤에서 휙 지나가는 걸 경험할 때마다 놀라는 것도 지치네요. 아무데나 던져놓듯 주차되어 있는 것도 진짜 보기 싫고요."',
#    '"없애라고요"',
#    '"인도에 아무렇게나 너부려져있는 거 사람들 발에 걸려 넘어지고 특히 밤에는 더 위험해."',
#    '"횡단보도 건널때 자주 세워져 있던데. 중앙 버스정류장에도 버리고 가더라. 지하철 앞도 그렇고. 시시티비에 다 보일거다. 모르는척 쇼질 그만하고 잡아서 견인비랑 딱지 떼어라. 한 50만원씩. 돈없으면 구류 5일이다. 뉘집 귀한 자식이고 반성 한다고 선처 이런 멍소리 하지말고 공평하게 \\n집행 하도록. 주 5일 근무제에 딱 들어 맞는군. 개똥 같은 법은 만들면서 뒤처리는 나몰라라."',
#    '"없애는게 답"',
#    '"이거 허가한 x부터 잡아들여야. 안전도 안전이지만 주차공간도 없이 공유지를 무상 주차장으로 업자에게 내준건 도저히 이해할수 없다."',
#    '"킥보드는 왜 차로에서 당연하듯 역주행하는가\\n운전하다 박을 뻔 했다."',
#    '"돈먹고 밀어붙이 국개들이 누군가봤더니 국짐 소속 윤 재 옥 국회의원 어휴 국민의 적"',
#    '"킥보드 없어졌음 좋겟네요~진심 볼때마다 아무데나 놓여져잇고 쓰려져있고.후..볼때마다 누가 저렇게 놓는걸까..하는 생각도 하네욘~"',
#    '"킥보드 렌트 사업은 없어져야한다! 도로가 너무 위험해졌어 지저분해지고"',
#    '"제발 다 없애라!! 길거리 동네할거없이 너저분해서 진짜 꼴보기싫다!"',
#    '"이용자들 인성이 개차반인것도 문제 아니냐? 길 한가운데 덩그러니 서있어 타고가다가 증발 한 줄...ㅋㅋ"',
#    '"인도에 있는것부터좀치워라\\n왜길을막고 지 . 알이냐"',
#    '"공원산책로 중간에 떡하니 세워놓고 가는 무개념 인간들도 있더라"',
#    '"킥보드법 안만드냐? 무슨법! 무슨법 잘도 만들면서 킥보드법은 왜 안만드는겨? 1일 사고가 얼마나 나는줄 알어?"',
#    '"개념없게 주차된 킥보드 볼때마다 개박살내고싶더라"',
#    '"헷멜 착용안하면 벌금 물린다더니 왠걸 난 여태 헬멧쓰고 댕기는 사람 한명도 못봤다 맨날 입으로만 나불나불 진저리난다"',
#    '"킥보드 싹 치워라"'],
#   ['"시행자수준  이용자 수준을 이제  모두  알았으니  폐지하는것이  정답이다.."',
#    '"길거리에 막 세워놓고 눕혀놓고 쳐박아놓는 씽씽이부터좀 어떻게해라"',
#    '"어떤양반이 생각없이  허가해줬나요?\\n책임지고 허가 취소하세요."',
#    '"제발없애라"',
#    '"번호판부착의무시키고 과태료 10만원씩해라"',
#    '"저거 국민 세금으로 치우고 있는거라면서요? 당장 전동 킥보드 다 금지 시키세요!"',
#    '"없애라 제발... 밤에 운전하다 보면 얼마나 식겁하는데... 왜 지들 편하자고 차량 운전자들이 위험부담을 해야되나"',
#    '"문죄인 하는게 이꼴이지~~~~"',
#    '"주차위반시 벌금 10만원씩 때려서  국고로 사용하자"',
#    '"없애자니깐..휴~"',
#    '"니들이 세금만 축내려고 이딴걸 시행한걸 우리가 모를줄 아냐?"',
#    '"보증금 제도를 두면 되지않음? 지정된 장소에 파킹 안하면 타기전에 냈던 보증금을 안 돌려주는 방식같은거. 전 업체에 일괄 적용시키라고 하면 될듯 한데."',
#    '"자동차나 주차장&lt;PARKING ZONE&gt;에 잘 집어넣어리 도로좀 넓게쓰쟈 인도까지 침범하고 참..."',
#    '"불법주정차 견인하면 업체에만 책임 묻지 말고 마지막 이용자도 벌금 물게해라 그래야 바뀐다. 어짜피 암데나 세워도 업체만 책임진다면 이용자들은 안변한다. 마지막 이용 로그 확인하고 그 사람이 책임지게 해라."',
#    '"저비싼걸 이용하는 사람들도 이해가안감. 보기도 싫고 안전하지도 않고 심지어 비싸기만한 저 이동수단은 도로위의 쓰레기 그 이상도 하도 아닌데 말이지. 차라리 그냥 자전거를 세워 놓던지."',
#    '"솔직히업체가 부지런만했어도 이렇게 민페덩어리는안됬을듯 무게제한두고 신고들어오면결제정보로 그시간대 gps 해서 범칙금때리면될텐데"',
#    '"공유 킥보드 싫어여!!!"',
#    '"좀 없애라...그럼 교통사고 줄어든다..."',
#    '"저딴 쓰레기 물건 다 버려라  남의 집 대문 앞 횡단보도 코너  교통방해 보행자 방해   저딴거 모는 인간들은 불법투성이 킥라니  그 이상 이하도 아니다"',
#    '"개판오분전인거 알지? 둘이타고 헬멧은 있지도 않고 심지어 인도로 씽씽 달리며 안비킨다고 즤이랄\\n사고나면 우짤라고하는지"'],
#   ['"킥보드에 자전거에 길바닥이 개판이야 관리안되면 다 없애 버려라"',
#    '"이거 타는 나이대가 10대20대 주임\\n물론 그위에 나이대도 타지만..\\n마치 지들은 신교육받고 기성세대와는 다르다고 외치지만 똑같음 ㅋㅋㅋㅋ"',
#    '"아이들 등교하는 좁은 길앞에  버려놓고 도망간인간!!!\\n어린 애들이 너때문에 다치면 책임질거여?\\n엄마들 열받아서 욕한바가지씩했는데 장수하것네?\\n중고딩놈 두놈은 헬멧도 안 쓰고 둘이 타고 쌩하고 지나가는데 사고나면 크게 다치는거 알면서 어찌 그러다 차길로 다니는지 느그 부모는 느그 그러고 다니는거 아나? 사고나면 느그부모 참 기뻐하긋다!!!\\n여기저기 발에 치이고쓰레기 공해다!!! 제발 좀 다 없애버려라!!!"',
#    '"초과세수~ ㅋㅋ"',
#    '"썩을것들이 차뒤에다가 옆에다가 앞에다가\\n사방팔방 하... 사용후제발 잘좀세워두고가라 사용자분들!"',
#    '"이파트에 몇달째 방치된 킥보드, 사용하지도 않는데 어플 깔기 싫어서 문의할 곳 찾다가 아무리 찾아도 문의할 전화번호나 메일이 안나와서 다시 킥보드있는데사서 자세히보니 메일주소가 있길래 거기다가 사진과 주소, 위치 보내고 가져가라고 했는데 금방 조치 한다더니 2주째 안가져감. 정성스레 방치된거 제보해줘도 신경도 안쓰는듯함"',
#    '"킥보드는 아무 잘못도 없다. 사용하는 국민들 국민성이 후져서 그런거지. 내가 여기 킥보드 버려두고 가면 행인들에게 방해가 될까 안될까.. 이 단순하고 간단한 생각을 못함. 자기소유가 되고, 거기에 따른 페널티가 주어져야 나아질 거임. 자차 주차 감히 아무데나 할 생각 함? 똑같은 거임."',
#    '"주차장을 확보한 사업자만 운영하게 하면 되지! 주차장에 대지 않는 이용자는 이용권한을 회수하고."',
#    '"또 법 하나 만들려고 하네. 징역 2년형 합시다."',
#    '"방법은 정부가..국회가..공뭔들이..저런거 생기면 바로 유입되기전에 관련 법규 만들어야 하는데 일단 들어오고 누군가는 꿀 다~~빨고 이제 사건,사고가 되서 이슈가 되고 이목이 집중 되야 국회가 나서서 일하는척 하고 공뭔도 일하는 척을 없애면 된답니다."',
#    '"개똥같이 주차된 킥보드 다 부수고싶다. 물론 생각만 생각만"',
#    '"저녁에 감감한데 인도 정가운데 놔두어서 걸려 넘었졌다. 킥보드는 애들이나 좋아하는 장난감이지 다수의 사람들한테는 민폐다!"',
#    '"걸어댕겨 언제부터 그딴거타고다녔다고지랄들이야  그냥싱싱카나 타던가ㅋㅋ"',
#    '"골치덩어리 차에 받히면 이전에 주차해놓은 장신나간 이용자에게 손괴비용 청구할 수 있게 해야한다"',
#    '"불법주차 확인되면 바로 폐기..불법주차자는 모든 배상..끝"',
#    '"국토부에서 이런 사업을 계획하고 입찰한 것이 이미 문제였다는 것을!!!!!  사후문제는 시뮬레이션 해보지도 않고 국가재정으로 펑펑 돈 쓰는 사업에만 경쟁한 결과라는 생각이 드는군요"',
#    '"그래도 요즘은 킥라니들 많이 준거같아 다행인데 업체들 운다고 규제풀까봐 그것도 잘 지켜봐야한다"',
#    '"제도를 시행할 땐 그에 따른 문제점을 예측하고 대비책을 마련해야 하는데 무조건 벌려 놓고 혼란과 피해가 발생하여야만 그때가서 욕을 먹어야 대책을 마련하는 국회의원들과 공무원들이 문제다."',
#    '"전동킥보드 타는 사람들보면 미안하지만ㅂㅅ같음;;;"',
#    '"사업 취소해 주세요. 인도 주행, 2인승차, 안전모 미착용, 도로 역주행 등 온갖 불법 주행으로 안전을 해침. 특히 학생들 타는거 보면 매우 위험해 보임. 왜 낲뒤 안가리고 허가해 줘서.."'],
#   ['"돈 먹은 헬조선 종특이가 반드시 있겠지."',
#    '"빌라 진출입로에 주차 해놓은거 보고 웃음만 나오던데 ㅋㅋ"',
#    '"킥보드 없앴으면 좋겠어요. 좌우회전할 때 차도에 막 튀어나와서 택시들도 놀라던데"']],
#  [['"인도에 방치되어 통행에 방해가 되는 전동킥보드는 구청에서 수거해서 폐기처분하라."']],
#  [['"킥보드로 영업 못하게 해라. 인도에서 무단주차하고 사용료도 안낸다. 사고위험도 높다."',
#    '"킥보드 자체를 없애 버려라~~~"',
#    '"운영업체는 견인료 보관료 개념없이 세워둔 고객에게 청구해라"',
#    '"킥보드뿐 아니라,\\n노란 자전거도 아파트여기저거 공원입구에 \\n팽개쳐  있네요"',
#    '"저렇게 아무데나 놔두다가 견인이나 파손되거나 사람이 다쳐서 업체에 손해가 발생하면 결국 사용자 비용이 올라갈텐데 왜그렇게 생각들이 없냐 일단 싸가지는 찾아볼수없고"',
#    '"이정권들어서  저사업하는 사람 승인한 사람들 관계가 계속 궁금한데  누가좀  조사좀 해주길   태양광처럼  지들 끼르 해먹는 사업  처럼 보임"',
#    '"이런걸 정책이라고 만든애들도 견인 부탁합니다"',
#    '"서울시 전동킥보드 사업 허가낸 관계자가 누구인가요?\\n 교육도 관련법도 잡히지 않은 상태서 중국돈이면 다되는거예요?\\n 도시미관과 품위는 어디로 갔죠? 서울시장이 죽기전에 온갖 똥싼거 고생스럽겠지만 치워주시길 정중하게 부탁드립니다."',
#    '"인도에서 전동킥보드 타는것들 단속해라"',
#    '"킥보드 진짜 타는거 보면 아이들 어르신들 장애인들 한테 위험해보입니다 이딴거 허락한 정부 책임져라"',
#    '"킥보드만 아니라 인도에 세워놓은 자전거, 오토바이도 견인해라!"',
#    '"견인하지 말고  고물상 트럭이 직접 싣고 고물 처리 해 가는거로 해라."',
#    '"킥보드 허가해준 시키 누구냐? 인도에서 막달리는데 ..아무데나 주차하게하고 도대체 핼멧쓰는이를 못봤다"',
#    '"다른건 이해한다 치자. 워낙 골빈애들이 많이 타고댕기니까. 근데 좁은 자전거도로 한가운데 세워두는 셰키는 대체 어떻게 이해를 해야되냐.  사람 셰키맞냐?"',
# ...
#    '"전동이라 바로 옆에 지나갈때까지 소리도 안나고 , 길가다가 부딪히면 그냥 죽을수도 있는 속도로 달리던데...법안 개정한 사람들은 차만 타고 다녀서 실상을 모르는건가요? 참 한심합니다. 인도에 타고 다니는 사람들 벌금 물려서 세수 확보하세요."',
#    '"조만간 누구죽고 그사람이름딴 법안 나온다. 지금도 위험한데 중고딩 막타게 법안을 만들어?? 이러니 180석준 개돼지라불리지"',
#    '"정작 규제해야할 부분은 오히려 더 풀어줌ㅋㅋㅋㅋㅋ이제 초딩새끼들이 타고다니다 한번 사망사고 나면 그때서야 부랴부랴 다시 규제할듯"',
#    '"전동킥보드 제조회사랑 국개의원이랑 커넥션있는지부터 조사해라"',
#    '"법이 좃.,.같.구나... 타고다니는 차 팔아버려야겠다 자라니에 이어서 전라니가 생기는구나 아니지 퀵라니냐? 미 ., 친것들"',
#    '"길거리를 다니다보면 실제로 빠른 속도로 위태롭게 다니는 전동퀵보드를 자주보게 됩니다. 볼 때마다 아슬아슬 가슴을 쓸어내립니다. 개조하지 말고 적정속도와 안전수칙을 잘 지켜야 합니다."',
#    '"사회가 발전함에 따라 규제도 같이 발전해야 사고를 예상할 수 있을 것입니다. 안전하게 킥보드를 타려면 모두가 주의를 하면 좋을 것같아요."',
#    '"위험한데...."',
#    '"원동기면허 필요한걸로 알고있었는데 아니었나?"',
#    '"나는 무서워서 못 타겠던데..바퀴도 작아서 자전거타다 넘어질때랑은 차원이 다르게 날아간다. 차랑 부딪히면 진짜 죽겠더만"'],
#   ['"그냥 놔둬 누구나 다 말짱하면  병원은 뭐먹고 사냐  장애인되거나 죽는사람도 있으야지 안그랴? ㅋㅋㅋㅋ"',
#    '"차도로 다니면서 신호는 다 무시하고 다니던데 이것도 벌금내게 해주세요ㅠㅠ"',
#    '"전동퀵보드 법 시급하다\\n별OOO 거리에 판친다\\n사고 무지 많이 날듯"',
#    '"누가 죽어야 법이 바뀌지 ㅋㅋ"',
#    '"안전장비 풀착용하고 도로주행할때 차속도 맞춰가먼서 차처럼 주행하면 클락션 울리는빈도가 많이줄어들긴하지만 \\n법에서 도로로달리라는데 도로가도 지랄 인도가면 인도사람친다고지랄 자도는 자도재대로깔린곳도없다.\\n이 시장을 죽이려고만하지말고 조율해나가야할 문제인데 \\n일부 무지한 4륜들은 도로가 4륜차것으로만안다\\n킥보드를 원망하기보다 도로교통법을 더 상기시켜서 안정화를 시켜야하는데 죽자살자 달려든다."',
#    '"그냥 법을 만드시는게"',
#    '"이번 주말에 큰 공원에서 초등학생 하나가 안전장비 없이 전동자전거를 타고 누웠다가 다리를 올렸다가 엎드렸다가 곡예하며 타고 있더라.. 산책하거나 운동하는 사람들, 아이들, 반려견들 사이를 비집고 타는데 부모가 무슨 생각으로 줬는지.\\n저런 이동수단 확실히 조치가 필요할듯"',
#    '"우리나라는 법제도가 문제다.\\n이 세상에 자동차면허로 오토바이를 운전할수 있는 나라는 우리나라밖에없다.차랑 오토바이랑 운전하는 방식부터다른데 전동킥보드라...."',
#    '"그래  이나라 이제 갈때까지 가보자\\n억울한 죽음만  만들지 말라 \\n혼자 ㅈㄹ하다 혼자 골로가는건  아무도  막지않겠다\\n그게 신생아(?)든  어린이든 노인이든 누구든. 동정도 1도 않겠다 \\n가는길은 제발 혼자  가시길.축복은 해줄테니.\\n이갈린다 이나라 이도로에서 전동킥보드가 맞는거냐\\n이건 완전  국민들끼리 서로 치고박고 싸워라 이느낌임. 법도없고  관리도  단속도 엉망진창에다  안전의식도  제로."',
#    '"커플들 둘이서 같이 킥보드 한대에 타고 슝슝가는거 보면 말이 안나옴 ㅎㅎㅎㅎ"',
#    '"아무데나 세워놓는것도 문제입니다.\\n각 주택마다 아파트단지마다 도로곳곳에 무차별적으로 세워져있어서 보행 차량통행에도 엄청난 방해가 됩니다. 업체에서 불법방치되어있는 전동킥보드 책임지고 회수하세요."',
#    '"처벌을 할수없으면 법을 만들어라"',
#    '"위험하군요"',
#    '"아니 차도는 불법아닌가.. 교통 들은 머하는겨"',
#    '"그놈에 법..당장시행해야지 유예기간은 도대체 모냐"',
#    '"누구하나 죽어나가야 그때가서 규제하겠지머 ㅋ"',
#    '"그냥 타라고 해~~대신 디져도 자동차에 책임지라고 하면 안됨"',
#    '"이런식으로 인구 줄이기 좋구나"',
#    '"차에부디치면 참아플건데"',
#    '"단속 좀.."'],
#   ['"전기 자전거 스로틀모드&amp;패달  모드로  가는 거는\\n자전거 도로  통행금지  임니다  허나 퀵보드는\\n 자전거 도로 주행 가능 합니다   새로만든  자전거\\n 도로 법이  이모양 임 ᆞᆞᆞ"',
#    '"오늘도 전동킥보드가 차도에서 시속 60이상으로 달리더라"',
#    '"그래 빨리죽고싶으면.계속타~~~"',
#    '"오토바이 전면번호판 부착해라!생명을 위협하고 있다!"',
#    '"킥보드를 왜 차도에서 타죠? 불법아닌가요? 운전하다 킥보드 지나감 깜놀해요.. 혼자 죽지 애먼 운전자들 독박씌우려고.. 어린학생들도 타던데 이거 면허증 있어야하는걸로 아는데~~"',
#    '"잉?? 진짜 내가 4년전쯤 산 미니모터스 65km까지 나왔었는데;;;; 개조를 한걸 판건가;;;;"',
#    '"모든 운전면허와 킥보드 탑승권한에 운전적성정밀검사 1등급 통과를 넣고 못넘은 놈은 면허를 몰수해라"',
#    '"자격증 만들어서 세금거두겠내"']],
#  [['"도대체 어떤 힘있는놈이 이걸 허용햤을까? 얼마나 쳐드셨으면  이렇게 방치를 하는걸까?"',
#    '"길거리에 방치되어 있는 킥보드는 쓰레기나 다름없이 뒹굴고\\n안전성은 제로인 상태로 운행되고 있어 시민이나 운전자는 사고의 위험에 노출된 상태인데 관리 감독하는 부서는  일을. 하고 있는건지요?"',
#    '"사고시 어떤 보험에도 속하지 않는걸 저렇게 시에서 권장하다니 세종시 아쉽네요"',
#    '"많은 시민들이 죽거나 다쳐봐야 정신 차리겠냐 ?"',
#    '"세종시ㆍㆍㅠㅠ\\n너무너무 답답한 계획도시 ... 살고싶은도시 전혀 아닌 느낌을 받았다  근데 왜 아파트값이 저리도 오르는지ᆢ 허기사 공무원집합도시라"',
#    '"스마트시티 = 전동킥보드 ㅋㅋㅋㅋㅋㅋ 탁현민이냐?"',
#    '"아이들 등하교길 횡단보도앞에  떡하니 이건아니지않나요?\\n인도도 좁은데 그리 큰 킥보드에 애들 횡단보도 가다  \\n걸리고 치우려 들었더니 경보울리고 \\n이게 뭔가요? 여기저기  휙휙타다 던져놓고 \\n그만좀 합시다 안그래도많구요\\n운전하다보면  무척 불안하답니다."',
#    '"전동킥보드를 무인자동차나 드론처럼 미래의 최첨단 운송수단처럼 여기는 학계분위기 때문에 그런거다. 뭔가 거창하게 보이지만 실상은 원동기 달린 미니오토바이에 불과한건데 그걸 정책적으로나 도시계획적으로 적극 장려하니 문제가 되는거임."',
#    '"요즘 우리동네에도 저거 마구 보급되던데\\n진짜 인도로 달려오는데 사람하고 무딪혀 뒤로 넘어지면 몇명 골로갈것 같더라\\n속도가 자전거 풀페달 밟는것 같아."',
#    '"전동킥보드는 오토바이랑 동급"',
#    '"중국산 전동킥 수입업자와 정부/의원들과의 유착비리.... 꼭 다음 정권때는 밝혀내라... 행여 야당의원들까지 결부되었다면 특검이라도 하라고... ㅉ"',
#    '"전부 규제해라.. 공유서비스는 특히 더 함.. 인도에 차도에 여기저기 아무데나 세워두고 완전 흉물이 따로 없다"',
#    '"그동네 문빠 지부 조사해봐라..  문빠들 지부만들어서 지역마다 해처묵는다더라.,"',
#    '"그런데 길거리에 흉물이더라~\\n여기 저기 방치되어 있는게~"',
#    '"저놈의 전동킥 제재좀 해라 도보 고속활보에 길거리 아무곳이나 방치  차길주행 차간사이 주행 사고나기 딱 좋다. 제발 면허제로 하고 위반시 딱지 끊어라.."',
#    '"말이 스마트시티에 말이 전동킥보드지 까놓고보면 오토바이천지인 동남아의 전동버전ㅋㅋㅋ"',
#    '"딱 동남아네.\\n도시설계 좌좀식으로 해서 도로폭 ㅈ망에, 대중교통 ㅈ망이라 정작 차없으면 싸돌아다니지도 못하는데 근본이 ㅂㅅ인 도시에다가 저런거 허가내버리면 동남아도시 수준 되는거지ㅋㅋㅋ 동남아도시랑 요건이 똑같음"',
#    '"자동차 대수를 제한하자..\\n차를 없애라..자전거.킥보드.오토바이를 늘려라..\\n그러면 말이 달라지겠지.."',
#    '"미개인들에게 선진마인드를 기대한다는게 웃기다.짐승새끼들에게 킥보드를 주니까 저런 무개념운전들이 넘쳐나지."',
#    '"좁디좁은 땅덩어리에서   ...큰땅가지고있는 나라가 하는것들은  다하고 싶겠지"'],
#   ['"전동킥 서울시에 뿌려 놓고 보행자 안전 위협하는데 법적 기준도 없없다. 검찰은 실체를 확인해주길 바란다."',
#    '"세종시는 그럴려고 만든 도시인데 그걸 반대하는 시민은 무슨 논리냐?"',
#    '"도로에서도 위험 인도에서도 위험."',
#    '"헬멧 착용 의무화!! 인도주행 금지!! 오직 1인 탑승제!  최소한 이 3가지는 반드시 지키게 하고, 어길시 1건당 10만원의 벌금을 부과하라!  당신들 자식과 손주들이 크게 다쳐 봐야 정신 차릴것인가?"',
#    '"킥보드 발에 걸리면 부셔버려요. 그럼 적자가 심하면 망하겠죠."',
#    '"킥보드로 많이 죽어봐야 정신 차리지."',
#    '"전동킥보드 완전 편하던데 서비스 더 늘려라. 애들 무분별하게 타는건 단속하고. 애들만 따로 면허증 발급 받게 하던지."']],
#  [[]],
#  [['"전동 (킥)보드"']],
#  [['"안전장구 하고탑시다잉.."',
#    '"싸게만 살라고 인증안된거 직구쳐해서 그런거다..."',
#    '"전등 킥보드를 사실 때는 꼼꼼히 살펴보고 인증 마크가 있는지 방수 여부 등을 확인하고 구매해서 피해를 보는 일이 없기를 기원 합니다"']],
#  [['"빨리 법을 만드세요 차일피일 미룰일이 아닙니다 지금 개인용전동킥보드 폭주족들이 60-70은 애교요 120-130으로 폭주를 해대고 있습니다 똥오줌을 전혀 못가리는 상황인 지경에 이르렀습니다 똥인지 된장인지도 분간도 못하고 구별도 못하고 있습니다 빨리 불법개조처벌법이 들어가있는 PM법 빨리 통과시키세요 늦으면 늦을수록 보행자와 시민 행인들이 전동킥보드폭주족들 때문에 위협에 처해지고 있습니다"',
#    '"이기적인 전동차 대표야. 당신은 돈버는 일이지만 무분별하게 통행방해되고, 왜 남의 가게 문앞에 주차해서 피해주는건데"',
#    '"길거리  굴러다니\\n는거  아무나  페기처리 할수있게 해라 위험한고  쓰래기처럼 뒹글러다닌다"',
#    '"저는 전동 킥보드가 제일 시러요ㅠㅠ(소리 없이 다가와서 1미리 옆으로 스쳐 지나감 모골이 송연ㅠㅠ 내가 조금이라도 옆으로 이동햇다면ㅠ\\n그래서 계속 뒤돌아보는 습관 생김"',
#    '"이걸 왜? 하는건가요? 동네에 중학생들 둘이서뒹엉켜서타는거 너무 많아요  위험합니다  . 이건  진짜누가 책임지나요?"',
#    '"ㄹㅇ 위험함. 나이제한 있다 들었는데 그냥 막 타대"',
#    '"문제긴 문제인데 서로 논의하면 좋은 방안이 나올것 같은데 ..."',
#    '"민주당 의원들중 킥보드 업체 봐주기 관련있다 국민들은 피해보는데 당장 수사해라"',
#    '"불법으로 규정해서 싹다 없애버리는게 정답"',
#    '"무슨생각으로 이런걸만들었니\\n국민들  개 돼지만들라고만들었나\\n도로가에 걍주차해노코 ㅡㅡ 그러다사고나면?\\n진짜 아무대나 새워두고 쓰레기보다 더처치곤란이다\\n재앙아"']],
#  [[]],
#  [[]],
#  [[]],
#  [[]],
#  [[]],
#  [],
#  ['킥보드 길가에 무단 방치하고 며칠이 되도록 그자리에 버려 놓는데  ,이거도 문제지만 타는 애들도 헬멧도 안쓰고 인도로 막다니고 둘이같이 타고...이것도  아주 민폐다...',
#   '킥보드 2명이서 타는것좀 못하게 해라'],
#  ['지금이라도 늦지 않았다. 공유 퀵보드 사업 철회 해라~ 너무 위험해서 인도 다니기 힘들다',
#   '주차할때 인증샷 찍어야만 반납할수있게 시스템을 바꿔야 한다.\n주차가 아니라 그냥 길한가운데 버리고가는것들 너무 많다.',
#   '저런거 타고서는 육교 위, 통로 한가운데, 아파트 출입구 중간, 공원 잔디밭 구석 이런 곳에 쑤셔박아놓는 것들의 뇌구조가 정말 궁금하다...\n어떤 교육을 받고 자라면 그따위로 행동할 수가 있는걸까??\n반납장소를 따로 정해놓고 이용할 수 있도록 해야한다.',
#   '무법의 극치!!  이거 허용한  넘들이 치워라',
#   '지하철 카드 반납처럼 \n제자리 정리해야만\n비용 돌려받는 보증금 제도 하면\n좋겠어요',
#   '하여간 길거리 아무데나 방치된\n킥보드 여간 볼성사나운게 아닙니다.\n심지어는 차도에까지 널부러저 있는\n경우도 많습니다.\n사용자가 아무렇게나 방치 하는 것도\n문제이고 관리 회사가 관리를 제대로\n안하는 것도 문제이다.\n킥보드 주차장을 만들어서 정해진 \n장소에다 반납하게 하고 정해진 장소 이외에\n길거리에 방치 한것들은 모두 수거해서\n국고로 귀속시키세요',
#   '남의 장사하는 문앞에 덕커니 주차? 해버리고 손으로 옮기니 드렇게 무겁고 삑삑 소리도 나고.\n아무곳이 주차할 수 있게 하지말고 그래도 일정공간에 주차할 수있게 해야지.. 자동차도 불법주차 단속하는데\n전동킥보드도 이륜(오토바이)과 동일한 법규에 있는데 주차부분이 빠져있다. 타는 놈들중에 운전면허 없이 타는 넘이 50% 이상일거고 아무튼 개정시 반드시 불법주차 시 업주도 물고, 거기 새워둔 넘도 벌점으로 줘서 아예 운전자차를 못하게 해야한다.',
#   '진짜 타는 사람들도 문제가있지만 이걸허가해준인간부터 감방에좀처넣어라 진짜쓰레기보다 못한전동킥보드   길가에 몇일씩방치되어있다 쓰레기통에다버려라 걸어다니다 안전사고나면  누구책임이교',
#   '처음부터 이런 부분까지 세심하게 고려를 했어야 하고, 위반시에는 사용자에게 책임을 물어야 하지 않나?\n내동댕이 치는 사람 따로 있고 치우는 사람 따로 있다는 자체가 문제인 것 같은데...',
#   '누가? = 사용료 받는  해당 사업자\n너무나 당연한 얘기 아닌가?\n이에 불만이라면  식당 설겆이도 구청직원이 해 줘야 하나?',
#   '전동킥보드를 빌려줄 때 예치금으로 수거비용을 추가해야하는게 맞다고 봅니다. 그리고 자전거처럼 지정거치대를 만들어야 한다고 생각합니다. 아니면 지정라인을 만들어 세워 둘 수 있게 하면 어떨까하구요. 편의도 중요하지만 이건 아니라고 봅니다. 주차장에 있는 건 양반이고 심지어 8차선 왕복도로 중앙분리대에 있는 것도 봤습니다.\n빌려줄 때 예치금 받고 지정된 위치에 세워두면 다시 돌려주는 방식으로 하면 좋을 듯 합니다. 그래야 아무 곳에나 버리지 않죠..',
#   '전동킥보드가 들어온 경위부터 수사해라~~도대체 어떤놈이 일을 지시한거냐?',
#   '아파트 중간출입구에 가로로 하얀색 킥보드 두개 세워둬서 자전거도 못지나가고 걸어서 걷는 사람은 넘어다녀야 하는 현실.\n 아무렇게나 세우는 킥보드 제자리에 안세우면 사업자가 벌금 맞고 사업자는 소비자 제한하고 이런식으로 법개정해야 할 듯',
#   '꼭 견인조치를 해주시기를 바랍니다. 무분별한 주차 정말 짜증납니다.',
#   '킥보드 업체가 돈은 벌어먹고 왜 행복도시자전거순찰대가 정리는 하는지 ?',
#   '아직은 시민의식이 낮아서\n창피하군요.',
#   '인건비외 비용은 업체에 청구해서 받기를....\n비용이 늘어나야 자구책을 찾겠죠...',
#   '순찰대 280여명에 대해 우리 세금 단 1원도 쓰여지지 않았기를 제발 제발 간곡히 바래봅니다.',
#   '제가 경험한 사례 입니다.\n주차장 입구 한 가운데 세우고가서 후진 주차하다 사고 날뻔했고요..\n건물밖으로 나오다가 현관문에 세워두고간 퀵보드를 피하다 계단 밑으로 넘어질뻔 했어요..\n특히 노약자 보행자와 교통에 방해안되게 방법을 찾았으면 좋겠습니다.',
#   '제발 킥보드도 따릉이처럼 제 자리에 가져다 놓아야만 되도록 만들어라. 길거리 여기저기 흉물이다 흉물',
#   '하루에도몇번씩 이딴걸 대책없이 허가해준 놈 귀싸대기 후려치고 싶다.정말.',
#   '근시안적  정책이  이런사태를 일으키는거다\n처음에는좋치만 결국  모두를 피곤하게만든다',
#   '동영상찍고 전동킥보드나 전동자전거에 붙은 바코드찍어서 신고하면 최종사용자랑 그 회사에 벌금 물려라..',
#   '안전헬맷착용  1인 탑승\n안 지켜지고 있어요',
#   '돼지 목에 진주목걸이를 걸어준 셈이지.',
#   '전동킥보드 이용후 보행자의 통행에 방해되지 않도록 바르게 주차를 하면 좋겠습니다.',
#   '배터리 충전과 고장 회수 등 이런 문제는 업체가 용달 타고 다니면서 하는거 봤는데... 주차문제도 업체에게 의무적으로 맡기면 안되나? 보행자가 사고나면 그 배상책임도 업주가 지게~~',
#   '차도 주차장  차고지 증명하고  공유퀵보드도 주차장잇어야허가해줘야지  주차장이 없잔아  자동차. 퀵보드 도 자고지증명제 도입하라....',
#   '주차장이 없는 차는 허가취소해야지',
#   '1년에 3회이상 개판주차 적발시에\n공용이동수단 영구사용 불가처분 때려야함\n아직 우리나라에서 공용이동수단은 30년은 더 지나야 도입가능할 수단임',
#   '사후 관리가 안되는게   울  나라  현실!!!\n주차공간, 회수 등 이런것들  마련해서\n인허가를  내주야 하는데~~~ㅉ ㅉ\n대문앞, 인도 , 심지어  개인 주차장,  주차자 입구 \n등등   ~~~  개념이  없는  ㄴ많아요',
#   '아무데나 팽개치고 가면 끝 저런공유를 도대체 누가 허락했는지?? 한심하기 그지없다 ㅠㅠㅠㅠ',
#   '퀵보드 타다가 죽을 수 있다\n운동 삼아 걸어다녀~~~',
#   '저런걸 계도활동까지 해야한다는 것에 어처구니가 없다. 다른 사람들에게 피해가 않가게 놓아두어야 한다는 건 상식이 아닌가? 가정교육이 문제인건가? 학교교육이 문제인건가? 인성이 문제인건가?',
#   '따릉이처럼 입,출장소가 지정되면 효율적인데',
#   '전동킥보드 전철역 또는 버스정거장 관공서 어디던\n어지럽게 나뒹구는것 시민의 발걸음의 자짓하면 킥보드 전동차에 \n발등등 다칠 수 있는 위험한 쇠덩이다 다른 포장마차가 이렇게하면 \n관할구청서 철거단속한다 도로점령법의 적용된다 신속한 법적조치하라 \n관할구청 근무태만이다',
#   '하필 횡단보도에 주차하는 센스 역시 엘알세대',
#   '전동 킥보드 정말 심각합니다.\n너무 많은 업체가 생긴데다가\n\n사람들 없는곳에 있으면\n일주일이 지나도 아무도 타지\n않아서 방치 상태인데\n\n회수하라고 연락하면 외국회사라\n답장이 일주일뒤에 오고 그럽니다.\n그래서 구청에 연락해서 처리하죠.\n\n게다가 이 전동킥보드를 개념없이\n주차하는 사람이 너무 많아서\n\n시각장애인들의 점자 보도블록위에도\n주차를 해놔서 장애인분들의 사고가\n우려됩니다.\n\n그리고 인도위에서 아이들 데리고 다니면\n너무 위험천만할때가 한두번이 아닙니다\n\n전동킥보드의 퇴출을 바랍니다.',
#   '새벽에 출근하는데  길한복판에  똭!  어이없더군요  업체도 업처지만  대여하는  인간들 생각이 궁금함',
#   '인천서구 킥보드 버스주차장 , 횡단보도에 두고 가버리네요..어제는 어떤 할머니 버스를 타려다 킥보드에 거려 넘어지는걸 봤어요. 단속 벌금 강력히 부탁드립니다.',
#   '프랑스처럼 타고 강에다 다버려야 없어질듯',
#   '알파카 킥보드다수거해가라 무면허운전에 각종범법행위가다일어난다.   결국은 인피사고까지생기더라',
#   '요즘 견인차가 차량견인은 안하고 킥보드 견인하고있네요',
#   '지쿠터는 부모님 계정으로 타고 다니기라도 하지, 스윙이나 다른 업체들은 아무나 타도 된다. 이게 법이라고 만든거냐?',
#   '전동킥보드나 전기 자전거  \n사용자들 교육 시켜라  아무곳에나\n사용후 방치해서 2차 사고시 누가\n책임지나 ?\n사용자  아니면 운영  책임자들인겨?'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['견인해야 합니다.\n주택가에 방치되서 \n타지도 않는 킥보드들이\n일주일이 넘어도 수거가\n되지 않습니다. 무단 방치\n심각합니다.\n\n심지어 시각 장애인 보도\n블록조차 이런 전동킥보드들이\n점거해서 큰 사고로 이어질까\n걱정스럽습니다.',
#   '공유자전거 공유킥보드\n\n거리를 정말 지저분하게 만든다\n\n모든 지자체가 강력하게 단속하길 바란다!!!',
#   '남의집  출입구 앞에도 세우고길 중간에도  심지어 횡단보도 건너려 사람서는 곳에도 세운다  제발 없애라',
#   '공공도로를 자신들 사업장으로 사용하는 게 무슨 사업이냐...-,.ㅡ\n애초에 사업모델이 얼척없는 거.',
#   '차를 렌트하고 불법 주정차나 신호 위반 벌금을 누가 내는가!\n마찬가지다 ~\n빌린 사람은 정해진 정상적인 위치에 가져다 놓을 책임과 의무도 함께 져야 한다고 본다  !',
#   '퀵보드 업체의 논리대로라면 강남 인도에 포장마차는 왜 철거되야 하는가?\n보행도로는 지자체의 자산이자 관리 대상이기 때문이다. \n보행자의 보행권을 위해서 지자체가 관리하는 것이다. \n그런데 갑자기 어 이거 4차 산업이요, 시장에서 우리 서비스를 원해요 하면서\n퀵보드를 갖다 놓고 영업을 하면 \n\n포장마차는 뭔가...상식대로 좀 살자.',
#   '그럼 말도 안되는 마구잡이 방치를 사업을 위해서 풀어야 하나요? 인도가 당신네 것도 아니고 무단 방치 시 벌금 부과하는 걸 애초에 생각 했었어야죠.',
#   '니들이 이용자 한테 책임을 묻지 못하는 건 니들 사정이고\n이를 막기 위해서 니들이 보증금을 받던 울머 겨자를 처먹던 니들이 알아서 하라고',
#   '좋은거 썼으면 지정된 장소에 잘 세워 놔야지.\n여기 저기 공해다!',
#   '사용하는넘들도 쑤레기고\n운영업체도 쑤레기다\n지정된 공간 안에서만 타게하라',
#   '길거리 곳곳에 널부러저 방치된 퀵보드\n보행자 통행은 물론 차량통행에도 불편하다.\n따릉이와같은 관리시스템이 필요하다.',
#   '강남,서초에도 하자!\n길거리에 무질서인 킥보드 덕분에 사고 위험이 많아요~\n이용자야 편하겠지만 그로인한 피해는 대다수 시민입니다.',
#   '6개 구청 멋있다!!!',
#   '넓은  땅 덩어리도 아니고, 인구도 많아 복자복잡한 지역에서 이건 원래 아니었던듯.',
#   '서울시 잘했습니다.',
#   '솔직히 맣해서 전동킥보드사업은 산업발전에 아무런 효과가 없습니다.',
#   '이런건 허가해주지마\n 어린애들사고난다\n신호도안지키고  인도활보\n무단유턴 운전자들겁나것드라 \n운전자가먼죄여 불안속에운전해야하나',
#   '깔끔하니 좋음!',
#   '처음에만 반짝.\n거리에 킥보드 타는 인간들 봐라.  10명중 8명은 \n헬멧 안쓰고 인도로 사람과 사람 사이로 지나  다닌다.',
#   '전동 퀵보드 그냥 없애라\n길거리 좁은 거리 횡단보도 대놓고 휙~지나가는거\n꼴 보기 싫다',
#   '업체 몇사람기분 맞춰주려고  사고나면 기사나 시민들 평생 장애인될 수도 있는데  내가 운전해본경험으로  운전직일때   제일 힘든게 킥보드다  역주행에 사고나면  대인되고  .  킥보드는 최고 사망인데  시민들 안전을 위해서는  기사나.    둘레길같은데서나 타는거지  그걸  차도로에서 타는건  상식 이하리고 본다',
#   '없애라',
#   '본인껀 돈 주고 사는것이 맞다\n타다가 아무때나 버리고\n차로에서 헬멧없이 막 타고...',
#   '무료로 빌려주는건 아닐진데 업체에서 개선노력이 부족같다  킥보드에 고유 번호판을 달아 미 반납시 . 견인시등  그 비용을 이용자측에  부담시키면 안되나요 이용자측 신분은 확인 될테니',
#   '건물 입구 바로 앞 계단에 두고 가는 놈들은 사람들 엿먹으라는건가 싶더라. 잘했다',
#   '아무대나 방치된건 무조건 벌금 뗘려라!\n대한민국 땅이 다 지네것아니다.',
#   '업체측의주장은 억ㅈ주장이고억울하면 업체에서임대당시넉넉한 보증금을선납해뒀다가제대로된관리를하면\n방치하는 일들ㅇ생길까요?',
#   '결국 잘못이용한 사용자에게 요금이 부과되겠군.',
#   '그럼 너희들 사업 모델이 잘못 된 거지. 불법주정차 등으로 인한 사회적 비용은 발생시켜 놓고, 그거 책임지랬더니 비용 부담된다고 앓는 소리 한다는 건 결국 여태까지 사회에 기생해서 돈 벌었단 얘기잖아?',
#   '밤에 어두운 자전거 도로 위에 퀵보드 누워 있어 사고날 뻔 했음.퀵보드 없애야 함. 아니면 따릉이처럼 지정된 장소 이외 주차시 벌금 물게 하든가.',
#   '우회전 하려는데 중학생정도 애들이 둘이나 타고서 역주행으로 주행하더라구요\n왜 이런건 단속 더디게 합니까?',
#   '제주에 있는것도 없애라~~',
#   '살인무기...인도 운행 금지..\n허가를 왜 했어..',
#   '건강을 격려해야 하는 국가가 짧은 거리도 걷지말고 타고 다니라 하네 거동 불편한 노약자는 없고 젊은애들만 타고다니며 사고만 내는 기기 없애야 한다',
#   '전동 퀵보드 왜 만들엇는지 이해가 안간다 \n길거리 80% 안전 장비 착용도 안하고 그냥 타고 다닌다\n게다가 신호등 앞에 무작위로 두고 가는사람 널렷다\n순간 빡처서 발로 차버리는경오 잇다',
#   '불법주정차를 하지 않을수밖에 없는 시스템을 업체가 고민해야지. 싸지르면 다인줄 알어?',
#   '너무 아무곳에나 세워두고 간다는 생각은 들긴 했어요..저렇게 사진처럼 전용 주차존을 만드는 것도 좋은 생각인것 같네요!',
#   '없애라',
#   '마지막 결재한 사람에게 청구하면되지.. 관리 안되면 장사를 하지 말아야죠.',
#   '하는 만큼 돌려 받는거...',
#   '불법주차는 업체가 해결 해야지 누굴 탓하냐 그거 해결 못하면 사업 접어라',
#   '길거리 아무곳에다가 세워두고...처리해야지. 아님 없애든가.',
#   '3차선으로 느릿느릿 다니다 2차선 넘어오고 그러던데 불안해서 뒤에서 운전을 못하겠더라.',
#   '그런 시장 꼭 존재해야 하는 게 아니라 위축돼도 상관없음',
#   '잘한거지 서울시 .',
#   '불법주차된 차량부터 전부 없애라 \n서민들 타는 그 쪼그만 킥보드만 가지고 난리치지말고.\n\n빚내서 차사는 과시 문화 때려치우고\n시내에서는 킥보드 타고 다니는 문화 만들어야\n기름값 아끼고, 사고 줄고, 교통체증 줄고, 미세먼지도 줄어든다.',
#   '이용한 사람한테 받어 차빌리는 것도 벌금같은거 당시 운전했던 사람한테 부과하잖아',
#   '제대로 주차해서 사진 찍어 전송해야 시용료과금이 증단되게 히면 되짆아 멍청이들아.',
#   '이 같은 비용 부담에 일부 업체는 불법 주·정차 시 이용자도 과태료를 물도록 약관을 변경했으나, 업체 대다수는 이용자 감소를 의식해 \'울며 겨자 먹기\'로 버티고 있다. \n업계 관계자는 "전체 전동킥보드 이용자가 감소한 것이지 불법 주정차가 줄어든 게 아니다"라며 "불법 주정차를 해도 이용자로선 손해 볼 게 없는데 인식이 바뀌겠냐"며 반문했다\n?\n논리라고는 1도없는 업체사람들 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ\n그런데 따릉이는 관리 잘 되는데 왜 전동킥보드는 개판인지 모르겟네',
#   '전동킥보드 진짜아무데나\n세우고 길목 막아 놓고 가고\n스트레스 주는건 맞다\n규칙이 필요하다',
#   '가 가져가고.  벌금 100만원씩 때려라.\n무단 방치. 무단 주차.',
#   '필요없는 시장은 사장되기 마련이지',
#   '자전거에 전동킥보드에 갑자기 왜 사람다니는 길에 저런게 서 있는거야? 자전거 무료 대여 왜 하는거야? 쓸데 없는데 세금이나 쓰고.',
#   '불법주차 차량만 없어져도 도로한차선은 킥보드 전용으로  써도 되겠다.',
#   '불법주차비용은  관리책임이 있는 업체가 부담하는게 당연하지  그럼 누가 부담하냐??',
#   '길거리 아무데나 방치되어 , 발에 걸려 넘어진 사람도 보았다,  문재인 정권으로 부터 어떤 혜택을 받았길래, 이렇게 무도한 사업이 있나 했다, 사고율은 최고란다,  갑자기 뛰어 드는 보드와 충돌하여 억울하게 가해자가 되는 사람들은 또 무슨 죄인가?',
#   '서로공존해야지\n무조건단속만하냐\n세금만뜨더내려고혈안이지\n그업체도먹고사려고하는일인대\n서로조율혀서다른해법을\n찾아라'],
#  [],
#  ['장려한다고??  뭐 이런 밋틴놈들이 다 있어.  땅 좁고 사람 많고 개 많고 오토바이 인도로 다니지만 그래도 세계적으로 대중 교통 잘되어 있는 이 서울에서 왜 스쿠터 같은 걸 장려하고 난리지?   \n\n누가 돈 쳐먹고 있거나, 아무 생각 없는 게 분명.'],
#  [],
#  [],
#  [],
#  ['솔직히... 마지막 이용한 인간들한테 벌금 때려야 되는거 아니냐?',
#   '퀵보드 없애야 한다 살인무기일뿐이다',
#   '저따위 행정에 승인한 인간이 누군지 알고싶다!저딴 쓸데없는 돈 들어가게 만든 공무원좀 자르던지 감봉하던지 그런 정책좀 만들어라!',
#   '잘했네 ~~젊은이 한사람 타다가 죽는거보다\n   났네~~계속해서   해야  없어지지~~\n잠깐   단속하는척  하다 요즘 헬멧쓰고  타는사람  있어요?',
#   '제자리 안갖다놓는것들 천만원씩 벌금 내게합시다',
#   '비싸요.이용료..자전가가 ..싸고국민건강..\n안전에도움되는디 ..일산도..더그려요..누가..이익있 돈벌이에...왕창버는지..'],
#  ['공유 킥보드는 마지막에 놓은사람 추적해서 부과시키는건가? 제발 사람다니는 길 길막좀하지마',
#   '전국적으로 시행해라',
#   '양쪽 다 부과해라. 그리고 개념없는것들은 타지 마라.',
#   '공유킥보드 폐지해라.길거리에 마구 버려서 엉망이다.',
#   '그냥 없애라 사람 걷는 길에 따릉이 배달 오토바이 공유 전동킥보드 까지 \n인도에서 걷는 사람은 무슨 죄졌니?\n전시행정 그만하고 시민의 안전한 보행권을 보장하라',
#   '운영업자들이 지들 약관을 고쳐야지 뭘 어케하라고',
#   '마지막에 지정된 주차구역이 놔두지 않으면\n\n불이익을 줘야지. \n\n\n사용제한을 한다고나',
#   '업체는 견인 되는 킥보드에 대한 대처는 안하고 뭐했냐.. 강제로 대책 마련해라는 법이 없으니  개발 및 유지보수비 보다 벌금이 싸다고 계산하고 손 놓고있다가 저리 된 거 같은데..?',
#   '보여주기식으로 추진하고\n그끝은  아몰랑~~',
#   '일본 ▶ 문명\n어딜가도 반듯 정갈, 깔끔, 불법주정차 하나 없고 질서정연, 뭐하나도 깔끔하고 어딜가도 친절하고 괴팍하지 않고 남에게 피해안줄려고 하고 인간들 차분하고 염치있고 안싸우고 남 등 안치고..사회 시스템 좋고 심지어 야쿠자들도 점잖어. \n\n한국 ▶ 완전 야만소굴\n온천지가 아파트,온천지가 불법주정차,노점,인도는 상가물건에. 스피커소리에.길거리 간판,건물 뭐하나 정리정돈 안되있고 난장판에,불결하고 더럽고,상점들은 불친절에 눈탱이에, 비위생에, 인간들 괴팍하고 시끄럽고 뻔뻔하고 염치없고 사기꾼 천지에,길가 곳곳에 쓰레기 더미'],
#  [],
#  ['배터리와 모터출력이 중요하지.\n어차피 그거 알면서도 가격때문에 사는건데 초딩인가?'],
#  ['인도에서 헬멧도 안 쓰고 무개념으로 킥보드 타는 것들 단속 좀 해라. 아주 개판이다. 이제 마음 놓고 인도도 못 걷는 상황이다. 소리도 없이 인도에서 행인들 위협하면서 고속으로 스치면서 지나가는 것들 단속 좀 해라.',
#   '긍정적 효과보다 부정적 효과가 많은 사업\n그냥 킥보드 회사만 좋은 일이지\n세금으로 만든 도로를 왜 지들이 맘대로 보관장소로 쓰는지?',
#   '길가운데 주차해  통행방해\n남의집  대문앞에 주차 문여는데 방해\n인도로 돌진해 사람다치거나\n헤아릴수 없을 만큼 만다\n백악이 무효\n빨리  없애는게  특효약',
#   '가격은 나몰랑 하고 성능타령하는게 초딩이지.\n오토바이보다 비싼 놈은 왜 비교하는데'],
#  [],
#  ['맞는 말 했네',
#   '주차장입구에세워두는싸가지',
#   '우리동네 도로 1차선에 퀵보드가ㅡㅡ떡하니 있었다ㅡ\n거기다 늫은 사용자도ㅡ참내 생가이 있는건지ㅡㅡ\n업자들은 왜 수거도 안하는지ㅡㅡ3일을 있더라ㅡ',
#   '당연히'],
#  ['아무데나 세워두기도 하지만 모퉁이에도 세워둔다\n근데 더 짜증나는건 좋게라도 세워둠 통행에 그나마 덜 방해 되는데\n넘어트려 놓고도 그냥 간다는 거다.\n어린학생들 제재없이 많이 타던데 \n안전장비 하나도 없이 심지어 2명도 타고 \n이걸 탈수 규제도 제대로 만들지 않은 상태에서 탈수 있게 허가 내준게 진짜 어이가 없을 정도\n대체 윗 선에서 얼마를 받음 무작저 허가부터 하는지 원',
#   '길에 아무렇게나 방치하는거보면 저걸 주로 사용하는 나이대들의 무개념을 볼 수 있음',
#   '주차장 출입구에 두면 킥보드 깨 부시고 싶더라',
#   '왜 이제야 실행하는고 ?',
#   '오세훈 일 잘하네'],
#  ['널브러진전동킥보드탄사람을 핸드폰과신분확인해서 아에못타게만들어라 자전거역시마찬가지 다른말이지만 전동킥보든 자전거든 전국에있든데 자기집에놔두고타는사람있드라 심지어는**마켓이나 **나라에파는사람도있고~',
#   '없애도 될거 가지고 ㅎㅎㅎㅎ',
#   '싹다 쓸어갔음 좋겠다 도데체 저런거는 누가 허가 해준거야',
#   '야밤에 보도위로 자전거 휙휙 지나가는거 위험해보이던데 정부에서 확실한 조치를 취해주시기 바랍니다',
#   '안전하고 쾌적한 환경을 만듭시다'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['전국적으로 실시해라\n아주 개판이더라', '전국적으로 킥보도취소했으면']]

# %%
with open('./topic6_dict.pickle', 'wb') as f:
    pickle.dump(topic6_dict, f)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.hist(topictable['similarity'])
plt.show()

# %%
f, axes = plt.subplots(2, 3, figsize=(8, 6), sharex=True)

for i in range(2):
    for j in range(3):
        df = pd.DataFrame(topic6_dict['No_topics']).value_counts()
        df.plot.pie(autopct='%.2f%%', ax= axes[i,j])
                
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_30980/2278196783.py in <module>
#       3 for i in range(2):
#       4     for j in range(3):
# ----> 5         df = pd.DataFrame(topic6_dict['No_topics']).value_counts()
#       6         df.plot.pie(autopct='%.2f%%', ax= axes[i,j])
#       7
#
# KeyError: 'No_topics'

# %%
model_saved.print_topics(num_words=20)
# Out:
# [(0,
#   '0.018*"전동킥보드" + 0.016*"견인" + 0.015*"공유" + 0.014*"주차" + 0.013*"업체" + 0.011*"자전거" + 0.011*"서울시" + 0.009*"불법" + 0.009*"구역" + 0.007*"안전" + 0.007*"도로" + 0.007*"방치" + 0.007*"주행" + 0.007*"이용" + 0.006*"PM" + 0.006*"인도" + 0.006*"보행자" + 0.006*"문제" + 0.005*"시행" + 0.005*"관련"'),
#  (1,
#   '0.023*"충전" + 0.021*"제품" + 0.018*"배터리" + 0.015*"화재" + 0.012*"발생" + 0.009*"전동킥보드" + 0.008*"사고" + 0.007*"아파트" + 0.007*"기준" + 0.007*"소방" + 0.006*"조사" + 0.006*"언론" + 0.006*"표시" + 0.006*"피해" + 0.006*"소비자" + 0.006*"공감" + 0.006*"판매" + 0.006*"공감_언론" + 0.006*"무단" + 0.005*"가격"'),
#  (2,
#   '0.025*"사고" + 0.021*"경찰" + 0.013*"면허" + 0.012*"전동킥보드" + 0.012*"운전자" + 0.012*"음주운전" + 0.011*"음주" + 0.010*"상태" + 0.008*"운전" + 0.008*"도로" + 0.008*"도로교통법" + 0.008*"처벌" + 0.008*"차량" + 0.007*"자전거" + 0.007*"취소" + 0.007*"자동차" + 0.007*"남성" + 0.006*"혐의" + 0.006*"단속" + 0.006*"장치"'),
#  (3,
#   '0.027*"사고" + 0.025*"보험" + 0.013*"이동" + 0.011*"가입" + 0.011*"전동킥보드" + 0.010*"수단" + 0.010*"자동차" + 0.009*"업체" + 0.009*"경우" + 0.009*"보상" + 0.008*"발생" + 0.008*"공유" + 0.007*"개인형" + 0.007*"개인형_이동" + 0.006*"이용자" + 0.006*"이용" + 0.006*"관련" + 0.006*"서울" + 0.006*"보장" + 0.006*"증가"'),
#  (4,
#   '0.027*"서비스" + 0.022*"모빌리티" + 0.020*"공유" + 0.012*"운영" + 0.010*"사업" + 0.009*"전동킥보드" + 0.009*"제공" + 0.009*"안전" + 0.009*"주행" + 0.008*"이용" + 0.008*"기술" + 0.007*"국내" + 0.007*"개발" + 0.007*"이용자" + 0.007*"시장" + 0.007*"씽씽" + 0.007*"기업" + 0.006*"업체" + 0.006*"자전거" + 0.006*"대표"'),
#  (5,
#   '0.020*"전동킥보드" + 0.020*"안전" + 0.017*"이동" + 0.016*"장치" + 0.016*"착용" + 0.015*"이용" + 0.015*"개인형" + 0.015*"개인형_이동" + 0.015*"헬멧" + 0.012*"도로교통법" + 0.012*"면허" + 0.011*"사고" + 0.011*"안전모" + 0.010*"이용자" + 0.010*"자전거" + 0.010*"범칙금" + 0.010*"시행" + 0.009*"개정" + 0.009*"운전" + 0.009*"단속"')]
